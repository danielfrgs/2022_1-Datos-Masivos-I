# %% [markdown]
# <a href="https://colab.research.google.com/github/blancavazquez/CursoDatosMasivosI/blob/master/notebooks/3a_funciones_hash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tablas y funciones _hash_
# ## Tablas _hash_
# Una tabla _hash_ es una estructura de datos que puede almacenar objetos, la cual permite realizar operaciones de _inserción_, _eliminación_ y _búsqueda_. Esta estructura de datos es particularmente útil cuando el número de objetos a almacenar es mucho menor al de todos los posibles objetos. En lugar de usar los objetos como índices, estos se obtienen mediante una función
#
# $$
# h: \mathcal{U} \xrightarrow{} \{0, \ldots, m\}
# $$
#
# donde $m$ es el tamaño de la tabla (es decir, el número de cubetas que tiene) y $\mathcal{U}$ es el conjunto universal.
#
# Las operaciones más comúnes de una tabla _hash_ son:
#
# * _Buscar_: Regresa la cubeta correspondiente al índice $h(x)$ en la tabla
# * _Insertar_: Agrega un objeto $x$, este se mapea a la cubeta $h(x)$
# * _Eliminar_: Quita el objeto $x$ de la cubeta $h(x)$
#
#
# En el caso ideal, el tiempo promedio para estas operaciones en una tabla _hash_ es $O(1)$.
#
# ## Colisiones
# El valor de $m$ depende del tamaño y la variedad de objetos que queramos almacenar. En general, se busca tener un tamaño de tabla lo suficientemente grande para almacenar todas las objetos distintas pero no demasiado grande como para requerir una cantidad de memoria considerablemente mayor a la que se va a utilizar. Tener un tamaño de tabla pequeño en comparación al número de objetos resulta en mayores _colisiones_, las cuales ocurren cuando 2 objetos distintas $\{x^{(i)}, x^{(j)}\}, x^{(j)} \ne x^{(j)}$ son mapeadas al mismo índice por la función _hash_ (es decir, $h(x^{(i)}) = h(x^{(j)})$). Al diseñar una función _hash_ se busca que sea rápida y fácil de calcular pero a la vez que tenga la mínima cantidad de colisiones.
#
# En muchas aplicaciones queremos reducir colisiones de objetos diferentes. Sin embargo, no es posible evitarlas por completo, por lo que es necesario emplear estrategias para lidiar con ellas.
#
# ### Encadenamiento
# Una de las estrategias más comunes para resolver colisiones se conoce como _encadenamiento_ y consiste en que cada cubeta de la tabla almacena una lista enlazada con todos los objetos que han sido mapeados al índice correspondiente. Es decir, si 2 objetos $x^{(1)}$ y $x^{(2)}$ colisionan, ambos se insertan en la lista enlazada de la cubeta a la que fueron mapeados. Las operaciones sobre la tabla quedan de la siguiente manera:
#
# * _Buscar_: Examina si un objeto $x$ se encuentra en la lista enlazada de la cubeta correspondiente a $h(x)$.
# * _Insertar_: Agrega $x$ a la lista enlazada de la cubeta correspondiente a $h(x)$.
# * _Eliminar_: Busca el objeto $x$ en $h(x)$ y lo elimina de la lista enlazada.
#
# En el mejor escenario todos los objetos se mapean distintos índices. En el caso ideal el tiempo de estas operaciones se mantiene como $O(1)$ pero en promedio es $\Theta(1 + \ell)$ para buscar y eliminar, donde $\ell = \tfrac{n}{m}$ es el tamaño esperado de las listas enlazadas.
#
# ### Direccionamiento abierto
# Otro método común para resolver colisiones es el _direccionamiento abierto_, en el cual se sondean cubetas hasta encontrar alguna libre o la que contiene el objeto que se busca. Hay varias formas de realizar el sondeo: lineal, cuadrático o usando doble mapeo.
#
# ## Familias de funciones
# La idea es definir una familia de funciones $\mathcal{H}$ y seleccionar $h$ de forma aleatoria e independiente de los objetos $x$.
#
# ## Propiedades de las funciones _hash_
# De manera más específica es deseable que las funciones _hash_ $h$ tengan las siguiente propiedades:
#
# * Uniformidad: Si todos los índices son igualmente probables. La probabilidad de generar un valor es $\tfrac{1}{m}$, donde $m$ es el número de valores diferentes. Esto es, el número esperado de objetos distintos que se mapean a cada índice valor es el mismo.
# $$
# P_{h\in\mathcal{H}}[h(x) = i] = \frac{1}{m}, \text{para cada $x$ y cada $i$}
# $$
# * _Universal_: Si la familia de funciones minimiza el número de colisiones.
# $$
# P_{h\in\mathcal{H}}[h(x) = h(y)] \leq \frac{1}{m}, \text{para cada $x \ne y$}
# $$
# _Casi-universal_: Si la familia de funciones es cercana a ser universal
# $$
# P_{h\in\mathcal{H}}[h(x) = h(y)] \leq \frac{2}{m}, \text{para cada $x \ne y$}
# $$

# %%
from abc import ABC, abstractmethod 
from math import floor, sqrt, exp

import random

import numpy as np
import matplotlib.pyplot as plt

# Para reproducibilidad
semilla = 123
random.seed(semilla)
np.random.seed(semilla)

# %% [markdown]
# ## Diccionarios en Python
# Los diccionarios de Python se llevan a cabo a través de tablas _hash_. Por ej. podemos almacenar 2 conjuntos usando esta estructura de datos.

# %%
o = {}
o['O1']=(0, 2, 0, 4)
o['O2']=(1, 2, 0, 2)
    
print('O1 = {0}, O2 = {1}'.format(o['O1'], o['O2']))
# Out:
# O1 = (0, 2, 0, 4), O2 = (1, 2, 0, 2)

# %% [markdown]
# También es posible hacer lo contrario.

# %%
o2 = {}
o2[(0,2,0,4)]='O1'
o2[(1,2,0,2)]='O2'

print('(0,2,0,4) = {0}'.format(o2[(0,2,0,4)]))
print('(1,2,0,2) = {0}'.format(o2[(1,2,0,2)]))
# Out:
# (0,2,0,4) = O1
# (1,2,0,2) = O2

# %% [markdown]
# Más generalmente podemos crear diccionarios usando cualquier tipo o estructura de datos al que se le pueda aplicar la función `hash`.

# %%
print('Hash de 1 es {0}'.format(hash(1)))
print('Hash de 3.14 es {0}'.format(hash(3.14)))
print('Hash de \'10\' es {0}'.format(hash('10')))
print('Hash de (1,2) es {0}'.format(hash((1,2))))
print('Hash de (1,2,0,2) es {0}'.format(hash((1,2,0,2))))
# Out:
# Hash de 1 es 1
# Hash de 3.14 es 322818021289917443
# Hash de '10' es -4680634541447121866
# Hash de (1,2) es -3550055125485641917
# Hash de (1,2,0,2) es -7331918113253585507

# %% [markdown]
# ## Creando tablas _hash_ en Python
# Definimos una clase abstracta para nuestra estructura de datos, especificando sus métodos principales.

# %%
class TablaHash(ABC):
  def __init__(self, n_cubetas):
    self.n_cubetas = n_cubetas
    self.tabla = [[] for i in range(n_cubetas)]

  def __getitem__(self, x):
    return self.tabla[self.h(x)]

  def __repr__(self):
    contenido = ['%d::%s' % (i, self.tabla[i]) for i in range(self.n_cubetas)]
    return "<TablaHash :%s >" % ('\n'.join(contenido))

  def __str__(self):
    contenido = ['%d::%s' % (i, self.tabla[i]) for i in range(self.n_cubetas) if self.tabla[i]]
    return '\n'.join(contenido)

  @abstractmethod
  def h(self, x):
    pass

  @abstractmethod
  def insertar(self, x):
    pass

  @abstractmethod
  def buscar(self, x):
    pass
    
  @abstractmethod
  def eliminar(self, x):
    pass

# %% [markdown]
# ## Familia $\mathcal{H}$ por método de división
# Comúnmente se busca diseñar funciones _hash_ $h$ que sean independientes de los objetos a almacenar. Un método general para crear funciones _hash_ se conoce como el _método de división_ y consiste en usar el residuo de la división del objeto y el tamaño de la tabla $m$, esto es,
#
# \begin{equation}
#     h(x) = x \mod{m}
# \end{equation}
#
# Es conveniente usar un número primo para $m$.
#
# Definimos una clase hija de `TablaHash` que implemente la función anterior. Para resolver colisiones usamos encadenamiento, esto es, cada cubeta o registro de la tabla es una lista que contiene todos los objetos que son mapeados al índice correspondiente.

# %%
class THMod(TablaHash):
  def h(self, x):
    return x % self.n_cubetas

  def insertar(self, x):
    self.tabla[self.h(x)].append(x)
  
  def buscar(self, x):
    return x in self.tabla[self.h(x)]
      
  def eliminar(self, x):
    self.tabla[self.h(x)].remove(x)

# %% [markdown]
# Probemos nuestra tabla con un conjunto 5 de números

# %%
enteros = [1, 10, 36, 78, 93]
n_cubetas = 11

thmod = THMod(n_cubetas)
for i,e in enumerate(enteros):
  thmod.insertar(e)
print(thmod)
# Out:
# 1::[1, 78]
# 3::[36]
# 5::[93]
# 10::[10]

# %% [markdown]
# ¿Qué pasa si tenemos una lista de objetos más grande?

# %%
enteros = [12454, 73523, 9865, 12310, 12, 864189, 882113, 27, 36, 39654, 4, 481, 1155, 634, 69, 782, 1232, 9433]

thmod_mas = THMod(n_cubetas)
for i,e in enumerate(enteros):
  thmod_mas.insertar(e)
print(thmod_mas)
# Out:
# 0::[1155, 1232]
# 1::[12310, 12, 882113, 782]
# 2::[12454]
# 3::[36, 69]
# 4::[4]
# 5::[27]
# 6::[9433]
# 7::[864189, 634]
# 8::[481]
# 9::[9865]
# 10::[73523, 39654]

# %% [markdown]
# Para evitar colisiones podemos aumentar el tamaño de la tabla. Suponiendo que  la función anterior es uniforme, ¿cuál sería la probabilidad de colisión si deseamos almacenar $n$ objetos en una tabla de tamaño $m$? Podemos calcular esta probabilidad como el complemento de la probabilidad que no haya colisión.
#
# $$
# \begin{align*}
# Pr[h(x) = h(y)] & = 1 - P[h(x) \ne h(y)] \\
# & =  1 - \frac{m}{m} \times \frac{m - 1}{m} \times \cdots \times \frac{m - n + 1}{m}
# \end{align*}
# $$

# %%
def cumple(m, n):
  prod = 1
  for i in range(n):
    prod *= (m - i) / m
  
  return 1.0 - prod

# %% [markdown]
# Este problema está relacionado a la _paradoja del cumpleaños_, en el cual se tienen un conjunto $n$ de personas y se busca calular la probabilidad de que al menos 2 personas cumplan años el mismo día. En este caso las probabilidades para diferentes valores de $n$ quedan de la siguiente manera:

# %%
import matplotlib.pyplot as plt

pcs = []
n_personas = range(1,90,5)
for n in n_personas:
  pcs.append(cumple(365, n))

plt.plot(range(1,90,5), pcs)
plt.xlabel('Número de personas')
plt.ylabel('Probabilidad de colisión')
plt.show()

# %% [markdown]
# Regresando al problema de las colisiones en nuestra tabla, las probabilidades para $m = 11$  serían

# %%
pcs = []
n_personas = range(1,20,5)
for n in n_personas:
  pcs.append(cumple(11, n))

plt.plot(n_personas, pcs)
plt.xlabel('Número de personas')
plt.ylabel('Probabilidad de colisión')
plt.show()

# %% [markdown]
# Podemos hacer más grande el tamaño de la tabla para reducir el número de colisiones. La probabilidad de colisión para $n = 18$ y diferentes valores de $m$ es

# %%
emes = range(1, 1500, 100)
n = len(enteros)
probs = []
for m in emes:
  probs.append(cumple(m, n))

# %% [markdown]
# En lugar de hacer el cálculo de la probabilidad exacta con la función `cumple`, es posible aproximarla de la siguiente manera:
#
# $$
# P[h(x) = h(y)] \approx 1 - e^{\frac{-n^2}{2m}}
# $$

# %%
def cumple_aprox(m, n):
  return 1.0 - exp((-n**2) / (2 * m))

aprox = []
for m in emes:
  aprox.append(cumple_aprox(m, n))

# %% [markdown]
# Graficamos las probabilidades de colisión con diferentes tamaños de tabla calculadas con las 2 estrategias

# %%
plt.plot(emes, probs, label='$P[h(x) = h(y)]$')
plt.plot(emes, aprox, label='Aproximación')
plt.xlabel('Número de días')
plt.ylabel('Probabilidad de colisión')
plt.legend()
plt.show()

# %% [markdown]
# Asimismo, podemos calcular el número esperado de colisiones para valores dados de $m$ y $n$ de la siguiente manera
#
# $$
# \mathbb{E}[\text{colisiones}] = n - m \cdot \left(1 - \frac{m - 1}{m}\right)^{n}
# $$

# %%
def n_colisiones_esperado(m, n): 
  return n - m * (1 - ((m - 1) / m)**n)

# %% [markdown]
# Para una tabla con 11 cubetas y 18 números a almacenar esperaríamos el siguiente número de colisiones:

# %%
n_colisiones_esperado(11, 18)
# Out:
# 8.978446689001352

# %% [markdown]
# El número de colisiones que ocurrieron para el caso anterior fue:

# %%
sum([len(c) - 1 for c in thmod_mas.tabla if len(c) > 1])
# Out:
# 7

# %% [markdown]
# Si aumentamos el tamaño de la tabla a 281 cubetas esperaríamos

# %%
n_cubetas = 281
n_colisiones_esperado(n_cubetas, 18)
# Out:
# 0.5342863185881868

# %% [markdown]
# Registremos los números en una tabla con este número de cubetas

# %%
thmod_grande = THMod(n_cubetas)
for i,e in enumerate(enteros):
  thmod_grande.insertar(e)
print(thmod_grande)
# Out:
# 4::[4]
# 12::[12]
# 27::[27]
# 30::[9865]
# 31::[1155]
# 33::[39654]
# 36::[36]
# 54::[882113]
# 69::[69]
# 72::[634]
# 90::[12454]
# 108::[1232]
# 114::[864189]
# 160::[9433]
# 182::[73523]
# 200::[481]
# 220::[782]
# 227::[12310]

# %% [markdown]
# Si tenemos más números para almacenar, el número esperado de colisiones sería:

# %%
n_objetos = 200
n_colisiones_esperado(n_cubetas, n_objetos)
# Out:
# 56.73636182748538

# %% [markdown]
# Veamos que pasa con nuestra tabla anterior si almacenamos 200 números

# %%
conj = np.random.randint(1000, high=5890123, size=n_objetos)
thmod_mas_grande = THMod(n_cubetas)
for i,e in enumerate(conj):
  thmod_mas_grande.insertar(e)
print(thmod_mas_grande)
# Out:
# 2::[189396]
# 6::[555543]
# 8::[821652]
# 11::[4968934]
# 14::[1956898]
# 17::[5309512]
# 19::[822787]
# 21::[4090819]
# 22::[5231680, 3817407]
# 23::[1574185]
# 25::[3710068, 347060]
# 27::[48078]
# 28::[4617139, 2289897]
# 29::[3439750]
# 30::[41337, 4024793]
# 31::[1720313, 628628]
# 32::[1242052, 2292430]
# 33::[2978633, 5600644]
# 38::[4327719]
# 41::[2166551, 337803]
# 42::[1324114, 4154065]
# 43::[892780]
# 44::[211637, 1749269]
# 46::[3454379]
# 47::[1650360, 220632]
# 48::[2821569]
# 49::[2707203]
# 51::[621904]
# 52::[5387103]
# 55::[755102]
# 57::[1963123]
# 60::[4242879]
# 61::[57385]
# 63::[1917045]
# 65::[3839087]
# 66::[5603206]
# 67::[1779359]
# 68::[3777270]
# 69::[2742067]
# 70::[5643674]
# 71::[1435419]
# 72::[970365, 2344174]
# 74::[1885584]
# 76::[5130574]
# 82::[276586]
# 83::[1563848]
# 85::[2670428]
# 87::[4657381]
# 89::[2411350]
# 91::[153798]
# 94::[971230]
# 96::[310882]
# 99::[3021130, 1952206]
# 100::[3287238]
# 102::[1271627]
# 104::[1493619]
# 105::[4791155]
# 106::[1594219]
# 107::[3656479, 4487958]
# 108::[267339, 1198011, 337870, 4679039]
# 109::[175172]
# 110::[3265611]
# 111::[1269950]
# 112::[250764]
# 115::[4606267, 2057878]
# 117::[278869, 3164458, 2205686]
# 120::[981934]
# 123::[2658102]
# 131::[462376, 3218143]
# 132::[642217, 2084309, 5449003]
# 133::[5777493]
# 134::[3698656]
# 137::[726522, 3561812]
# 138::[4724310]
# 139::[5804194]
# 141::[5089613]
# 142::[4991264]
# 143::[545845]
# 145::[983083]
# 147::[2675548, 2600521, 5330155, 2633398]
# 153::[170158, 4214310]
# 154::[3666361]
# 159::[3892571]
# 160::[3281116]
# 163::[3577574]
# 167::[2449363]
# 172::[1319748, 1978974]
# 174::[3450292]
# 175::[3165640]
# 177::[4224731]
# 178::[2379967]
# 180::[1956783]
# 182::[3241798]
# 183::[3800146, 4006681, 192668]
# 184::[2631187, 2423528]
# 185::[4223334]
# 186::[1819380, 210093]
# 189::[5128439]
# 192::[3250238]
# 194::[2616304]
# 197::[307330]
# 202::[3890085, 1889646, 4600734]
# 203::[3088955, 2934686]
# 204::[1990246, 1480231]
# 211::[4332107, 812863]
# 213::[2481724, 4506048]
# 214::[3157530, 2596373]
# 215::[5193657]
# 216::[933136]
# 217::[337698, 708899, 4813185]
# 219::[5780389]
# 221::[4324249]
# 225::[2294871, 2080187]
# 229::[2597793]
# 231::[5844750, 2929656]
# 232::[5777873, 3122423]
# 233::[5493783]
# 234::[4941057]
# 235::[3140129, 3989592]
# 239::[1410016]
# 240::[3109505, 3921314]
# 241::[4999231, 3352009]
# 243::[1823933, 311029]
# 246::[1295375, 2247122]
# 247::[1270367, 1640163]
# 248::[2911970]
# 250::[2059699]
# 251::[102816]
# 252::[655544, 593162, 1627523, 143843]
# 255::[2693640, 4101169]
# 258::[5290083, 3300041]
# 261::[1832662, 4513402]
# 263::[2787502]
# 265::[5219559, 5540461]
# 267::[4674140, 5423286]
# 268::[5048714, 3929210]
# 269::[502416]
# 270::[3484389]
# 274::[4982966]
# 279::[3201993]

# %% [markdown]
# Examinemos la cantidad de números mapeados a cada cubeta por nuestra función _hash_

# %%
cubetas = [c for c in range(n_cubetas)]
tam_cubetas = [len(c) for c in thmod_mas_grande.tabla]
plt.bar(cubetas, tam_cubetas)
plt.xlabel('Cubeta')
plt.ylabel(u'Número de colisiones')
plt.show()

# %% [markdown]
# El número de colisiones que ocurrieron es

# %%
sum([len(c) - 1 for c in thmod_mas_grande.tabla if len(c) > 1])
# Out:
# 60

# %% [markdown]
# ## Direccionamiento abierto
#
# En lugar de usar encadenamiento, podemos usar direccionamiento abierto resolver colisiones. En esta estrategia, si hay una colisión, se sondean otras cubetas o registros en la tabla hasta encontrar una libre. Si no hay ninguna disponible decimos que la tabla está llena y es necesario aumentar su tamaño para poder almacenar más objetos.
#
# Para determinar el siguiente índice a examinar es necesario extender la función hash para que incorpore la información de índice. Esta función debe garantizar que se examinen todos los índices en caso de que ninguno esté disponible.
#
# ### Sondeo lineal
# Una estrategia común para extender nuestra función _hash_ es el sondeo lineal, el cual está dado por
#
# $$
# h(x, i) = (h'(x) + i)\mod{m}
# $$

# %%
class THOA(TablaHash):
  def __init__(self, n_cubetas):
    super().__init__(n_cubetas)
    self.colisiones = np.zeros(n_cubetas)

  def sl(self, cubeta, i):
    return (cubeta + i) % self.n_cubetas

  def insertar(self, x):
    llena = True
    cubeta = self.h(x)  
    self.colisiones[cubeta] += 1
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if not self.tabla[ind]:
        self.tabla[ind].append(x)
        llena = False
        break

    if llena:
      print('Tabla llena')

  def buscar(self, x):
    cubeta = self.h(x)
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if self.tabla[ind][0] == x:
        return ind

    return -1

  def eliminar(self, x):
    cubeta = self.h(x)
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if self.tabla[ind][0] == x:
        self.tabla[ind].remove(x)
        return ind
        
    return -1

class THModOA(THOA):
  def h(self, x):
    return x % self.n_cubetas

# %% [markdown]
# Intentemos nuevamente con el conjunto anterior usando esta estrategia

# %%
thmodoa = THModOA(n_cubetas)
for i,e in enumerate(conj):
  thmodoa.insertar(e)
print(thmodoa)
# Out:
# 2::[189396]
# 6::[555543]
# 8::[821652]
# 11::[4968934]
# 14::[1956898]
# 17::[5309512]
# 19::[822787]
# 21::[4090819]
# 22::[5231680]
# 23::[1574185]
# 24::[3817407]
# 25::[3710068]
# 26::[347060]
# 27::[48078]
# 28::[4617139]
# 29::[3439750]
# 30::[41337]
# 31::[1720313]
# 32::[1242052]
# 33::[2292430]
# 34::[2978633]
# 35::[628628]
# 36::[5600644]
# 37::[4024793]
# 38::[4327719]
# 39::[2289897]
# 41::[2166551]
# 42::[1324114]
# 43::[4154065]
# 44::[211637]
# 45::[1749269]
# 46::[3454379]
# 47::[1650360]
# 48::[2821569]
# 49::[220632]
# 50::[337803]
# 51::[621904]
# 52::[5387103]
# 53::[2707203]
# 54::[892780]
# 55::[755102]
# 57::[1963123]
# 60::[4242879]
# 61::[57385]
# 63::[1917045]
# 65::[3839087]
# 66::[5603206]
# 67::[1779359]
# 68::[3777270]
# 69::[2742067]
# 70::[5643674]
# 71::[1435419]
# 72::[970365]
# 73::[2344174]
# 74::[1885584]
# 76::[5130574]
# 82::[276586]
# 83::[1563848]
# 85::[2670428]
# 87::[4657381]
# 89::[2411350]
# 91::[153798]
# 94::[971230]
# 96::[310882]
# 99::[3021130]
# 100::[3287238]
# 101::[1952206]
# 102::[1271627]
# 104::[1493619]
# 105::[4791155]
# 106::[1594219]
# 107::[3656479]
# 108::[267339]
# 109::[1198011]
# 110::[3265611]
# 111::[1269950]
# 112::[337870]
# 113::[250764]
# 114::[4487958]
# 115::[4606267]
# 116::[2057878]
# 117::[278869]
# 118::[3164458]
# 119::[2205686]
# 120::[981934]
# 121::[175172]
# 122::[4679039]
# 123::[2658102]
# 131::[462376]
# 132::[642217]
# 133::[2084309]
# 134::[3698656]
# 135::[5777493]
# 136::[5449003]
# 137::[726522]
# 138::[3561812]
# 139::[5804194]
# 140::[3218143]
# 141::[5089613]
# 142::[4724310]
# 143::[545845]
# 144::[4991264]
# 145::[983083]
# 147::[2675548]
# 148::[2600521]
# 149::[5330155]
# 150::[2633398]
# 153::[170158]
# 154::[3666361]
# 155::[4214310]
# 159::[3892571]
# 160::[3281116]
# 163::[3577574]
# 167::[2449363]
# 172::[1319748]
# 173::[1978974]
# 174::[3450292]
# 175::[3165640]
# 177::[4224731]
# 178::[2379967]
# 180::[1956783]
# 182::[3241798]
# 183::[3800146]
# 184::[4006681]
# 185::[4223334]
# 186::[192668]
# 187::[2631187]
# 188::[1819380]
# 189::[5128439]
# 190::[2423528]
# 191::[210093]
# 192::[3250238]
# 194::[2616304]
# 197::[307330]
# 202::[3890085]
# 203::[3088955]
# 204::[1990246]
# 205::[2934686]
# 206::[1889646]
# 207::[1480231]
# 208::[4600734]
# 211::[4332107]
# 212::[812863]
# 213::[2481724]
# 214::[4506048]
# 215::[3157530]
# 216::[933136]
# 217::[337698]
# 218::[708899]
# 219::[5780389]
# 220::[4813185]
# 221::[4324249]
# 222::[5193657]
# 223::[2596373]
# 225::[2294871]
# 226::[2080187]
# 229::[2597793]
# 231::[5844750]
# 232::[5777873]
# 233::[5493783]
# 234::[2929656]
# 235::[3140129]
# 236::[3122423]
# 237::[4941057]
# 238::[3989592]
# 239::[1410016]
# 240::[3109505]
# 241::[4999231]
# 242::[3352009]
# 243::[1823933]
# 244::[311029]
# 245::[3921314]
# 246::[1295375]
# 247::[1270367]
# 248::[2911970]
# 249::[2247122]
# 250::[1640163]
# 251::[102816]
# 252::[655544]
# 253::[593162]
# 254::[1627523]
# 255::[2693640]
# 256::[4101169]
# 257::[2059699]
# 258::[5290083]
# 259::[3300041]
# 260::[143843]
# 261::[1832662]
# 262::[4513402]
# 263::[2787502]
# 265::[5219559]
# 266::[5540461]
# 267::[4674140]
# 268::[5048714]
# 269::[502416]
# 270::[3929210]
# 271::[3484389]
# 272::[5423286]
# 274::[4982966]
# 279::[3201993]

# %% [markdown]
# ## Familias por método de multiplicación
# Otra estrategia para diseñar funciones _hash_ es el de multiplicación. En este método primero se multiplica el objeto $x$ por una constante $a \in (0,1)$ y se extrae la parte fraccional de $a \cdot x$. Posteriormente, se multiplica este valor por $m$ y se toma la función piso $\lfloor\rfloor$
# $$
# h(x) = \lfloor m  \cdot (x \cdot a \mod 1)\rfloor
# $$
#
# donde $a$ es una constante.

# %%
class THMultOA(THOA):
  def __init__(self, n_cubetas, a):
    super().__init__(n_cubetas)
    self.a = a
  
  def h(self, x):
    return floor(((self.a * x) % 1) * self.n_cubetas)

# %% [markdown]
# Aunque $a$ puede tomar cualquier valor en el intervalo $(0,1)$, hay algunos valores que funcionan mejor que otros. Donald Knuth recomienda $a \approx \frac{\sqrt{5} - 1}{2}$.

# %%
thmultoa = THMultOA(281, (sqrt(5) - 1) / 2)
for i,e in enumerate(conj):
  thmultoa.insertar(e)
print(thmultoa)
# Out:
# 0::[1885584]
# 6::[3021130]
# 11::[4006681]
# 12::[5777493]
# 16::[5449003]
# 17::[5231680]
# 19::[1480231]
# 20::[2693640]
# 21::[220632]
# 22::[5423286]
# 23::[462376]
# 27::[5290083]
# 28::[4968934]
# 31::[5130574]
# 32::[3165640]
# 33::[1319748]
# 34::[3698656]
# 35::[3710068]
# 38::[4679039]
# 40::[337870]
# 42::[971230]
# 43::[5844750]
# 44::[2166551]
# 45::[4724310]
# 46::[502416]
# 47::[189396]
# 48::[5804194]
# 49::[2289897]
# 50::[3088955]
# 51::[3892571]
# 52::[4090819]
# 53::[4941057]
# 54::[1978974]
# 58::[3281116]
# 59::[2344174]
# 60::[5540461]
# 61::[1563848]
# 68::[3777270]
# 70::[3839087]
# 71::[175172]
# 72::[2411350]
# 74::[1269950]
# 75::[2080187]
# 76::[2670428]
# 77::[593162]
# 78::[2294871]
# 79::[3817407]
# 81::[726522]
# 84::[3656479]
# 86::[1493619]
# 92::[3929210]
# 93::[822787]
# 94::[3577574]
# 95::[1779359]
# 96::[3921314]
# 97::[3241798]
# 98::[1242052]
# 99::[5643674]
# 100::[4224731]
# 101::[4154065]
# 102::[5600644]
# 103::[4982966]
# 104::[192668]
# 105::[2600521]
# 106::[2597793]
# 107::[2658102]
# 108::[307330]
# 109::[3800146]
# 110::[4674140]
# 111::[153798]
# 112::[4332107]
# 113::[1956783]
# 114::[1832662]
# 115::[3439750]
# 116::[892780]
# 120::[170158]
# 121::[2978633]
# 122::[4327719]
# 123::[2911970]
# 124::[4242879]
# 126::[3140129]
# 127::[1889646]
# 128::[555543]
# 129::[1324114]
# 130::[3989592]
# 131::[2707203]
# 132::[655544]
# 133::[628628]
# 134::[1956898]
# 135::[1640163]
# 136::[2633398]
# 138::[311029]
# 139::[3352009]
# 140::[2379967]
# 141::[3300041]
# 142::[3201993]
# 145::[1198011]
# 146::[278869]
# 148::[1594219]
# 149::[1627523]
# 152::[2821569]
# 153::[3122423]
# 154::[970365]
# 155::[276586]
# 156::[3250238]
# 157::[2057878]
# 158::[5193657]
# 159::[4606267]
# 161::[1650360]
# 164::[2449363]
# 165::[267339]
# 166::[1823933]
# 167::[3265611]
# 168::[3164458]
# 169::[2675548]
# 170::[2742067]
# 171::[5128439]
# 172::[981934]
# 173::[210093]
# 174::[5493783]
# 175::[4487958]
# 177::[3454379]
# 178::[4791155]
# 180::[310882]
# 184::[2292430]
# 185::[1952206]
# 188::[41337]
# 189::[1990246]
# 190::[1819380]
# 191::[4999231]
# 192::[708899]
# 193::[2423528]
# 194::[250764]
# 195::[2934686]
# 196::[755102]
# 197::[1749269]
# 198::[983083]
# 199::[1271627]
# 200::[3666361]
# 204::[3450292]
# 205::[1435419]
# 206::[337803]
# 207::[1963123]
# 210::[3890085]
# 211::[5603206]
# 212::[4657381]
# 213::[5387103]
# 214::[933136]
# 215::[545845]
# 216::[3218143]
# 217::[2247122]
# 218::[1295375]
# 219::[2481724]
# 220::[3109505]
# 221::[102816]
# 222::[2596373]
# 223::[2616304]
# 224::[4991264]
# 226::[2084309]
# 227::[621904]
# 228::[3287238]
# 229::[1410016]
# 230::[4506048]
# 231::[5089613]
# 232::[4214310]
# 233::[3484389]
# 234::[4617139]
# 235::[48078]
# 236::[337698]
# 237::[1574185]
# 238::[4513402]
# 239::[5048714]
# 240::[4101169]
# 241::[211637]
# 242::[4324249]
# 243::[5219559]
# 244::[5780389]
# 245::[4024793]
# 246::[347060]
# 247::[5309512]
# 248::[3561812]
# 249::[57385]
# 250::[821652]
# 251::[5777873]
# 252::[3157530]
# 253::[143843]
# 254::[1720313]
# 257::[2205686]
# 259::[4813185]
# 262::[642217]
# 268::[5330155]
# 269::[4223334]
# 270::[812863]
# 271::[1917045]
# 275::[2787502]
# 276::[2929656]
# 277::[1270367]
# 278::[4600734]
# 279::[2059699]
# 280::[2631187]

# %% [markdown]
# La cantidad de números mapeados a cada cubeta por esta función _hash_ es

# %%
plt.bar(np.arange(thmultoa.colisiones.size), thmultoa.colisiones)
plt.xlabel('Cubeta')
plt.ylabel(u'Número de colisiones')
plt.show()

# %% [markdown]
# El total de colisiones que ocurrieron en la tabla fue

# %%
np.sum(thmultoa.colisiones[thmultoa.colisiones > 1] - 1)
# Out:
# 57.0

# %% [markdown]
# ## Familia de funciones _hash_ universal
# Una familia de funciones universal es
# $$
# \mathcal{H}_{a,b}(x) = ((a\cdot x + b)\mod{p})\mod{m}
# $$
#
# donde $p \geq n$ es un número primo muy grande, $a \in \{1, 2, \ldots, p-1\}$ y $b\in \{0, 1, 2, \ldots, p-1\}$

# %%
class THUnivOA(THOA):
  def __init__(self, n_cubetas, a, b, primo):
    super().__init__(n_cubetas)
    self.a = a
    self.b = b
    self.primo = primo
  
  def h(self, x):
    return ((self.a * x + self.b) % self.primo) % self.n_cubetas

# %% [markdown]
# Instanciamos nuestra tabla con función _hash_ universal y almacenamos el conjunto de 200 números

# %%
a = random.randint(1, 104729 - 1)
b = random.randint(0, 104729 - 1)
thunivoa = THUnivOA(281, a, b, 104729)
for i,e in enumerate(conj):
  thunivoa.insertar(e)
print(thunivoa)
# Out:
# 0::[4982966]
# 1::[3088955]
# 5::[5128439]
# 6::[2631187]
# 7::[2821569]
# 8::[3250238]
# 9::[1963123]
# 10::[3561812]
# 11::[1324114]
# 13::[3484389]
# 14::[347060]
# 15::[4941057]
# 16::[3989592]
# 17::[1319748]
# 18::[2481724]
# 20::[5603206]
# 21::[2247122]
# 22::[307330]
# 23::[5804194]
# 24::[4090819]
# 25::[2205686]
# 26::[821652]
# 27::[3656479]
# 28::[655544]
# 29::[970365]
# 30::[628628]
# 31::[1242052]
# 32::[3157530]
# 33::[621904]
# 34::[4154065]
# 35::[1885584]
# 36::[4224731]
# 38::[211637]
# 39::[5777873]
# 40::[1435419]
# 41::[4024793]
# 44::[1410016]
# 48::[2693640]
# 49::[2597793]
# 50::[2057878]
# 53::[57385]
# 54::[981934]
# 55::[822787]
# 57::[933136]
# 60::[2292430]
# 61::[4506048]
# 62::[4657381]
# 63::[708899]
# 64::[545845]
# 65::[1952206]
# 69::[5449003]
# 70::[102816]
# 71::[4991264]
# 75::[3929210]
# 78::[5231680]
# 79::[1832662]
# 80::[210093]
# 81::[3140129]
# 82::[2658102]
# 83::[1269950]
# 84::[3800146]
# 85::[1823933]
# 86::[1627523]
# 87::[1990246]
# 88::[1889646]
# 89::[5387103]
# 90::[3890085]
# 91::[48078]
# 92::[2787502]
# 93::[3265611]
# 94::[1271627]
# 95::[3218143]
# 96::[4223334]
# 100::[189396]
# 101::[1493619]
# 102::[311029]
# 104::[1594219]
# 105::[5290083]
# 106::[1563848]
# 109::[3454379]
# 110::[5777493]
# 111::[3164458]
# 112::[3281116]
# 114::[278869]
# 117::[4487958]
# 118::[4724310]
# 120::[1574185]
# 122::[2411350]
# 123::[4813185]
# 124::[3241798]
# 125::[1270367]
# 126::[175172]
# 127::[3439750]
# 130::[2294871]
# 131::[3109505]
# 132::[3921314]
# 133::[41337]
# 135::[2084309]
# 136::[2080187]
# 137::[220632]
# 138::[3165640]
# 140::[2934686]
# 141::[1956783]
# 142::[755102]
# 143::[143843]
# 145::[2675548]
# 150::[337870]
# 151::[3021130]
# 152::[2379967]
# 153::[555543]
# 154::[1198011]
# 155::[2742067]
# 156::[2423528]
# 157::[4332107]
# 158::[4327719]
# 159::[4999231]
# 160::[267339]
# 161::[2633398]
# 162::[3666361]
# 163::[971230]
# 164::[812863]
# 165::[983083]
# 166::[642217]
# 168::[2670428]
# 169::[310882]
# 170::[2911970]
# 172::[5130574]
# 173::[4674140]
# 174::[276586]
# 175::[192668]
# 176::[726522]
# 179::[250764]
# 180::[3817407]
# 181::[462376]
# 182::[4006681]
# 183::[3287238]
# 184::[1749269]
# 185::[892780]
# 187::[2600521]
# 188::[1640163]
# 189::[4679039]
# 192::[2449363]
# 193::[3892571]
# 194::[4101169]
# 195::[4600734]
# 196::[5219559]
# 197::[2059699]
# 198::[1956898]
# 199::[4214310]
# 202::[1720313]
# 204::[337803]
# 206::[1978974]
# 207::[5089613]
# 208::[4617139]
# 209::[5493783]
# 212::[4606267]
# 213::[5600644]
# 214::[5193657]
# 215::[593162]
# 220::[3839087]
# 222::[3777270]
# 223::[337698]
# 225::[4513402]
# 227::[2929656]
# 230::[1917045]
# 232::[2978633]
# 233::[3352009]
# 234::[5048714]
# 235::[2616304]
# 237::[5540461]
# 238::[5643674]
# 240::[4324249]
# 243::[2166551]
# 246::[3698656]
# 247::[1819380]
# 248::[2289897]
# 249::[170158]
# 251::[4242879]
# 252::[5423286]
# 253::[1480231]
# 256::[5780389]
# 259::[3300041]
# 261::[3710068]
# 262::[5844750]
# 263::[3577574]
# 264::[3450292]
# 266::[1650360]
# 267::[3201993]
# 268::[4791155]
# 269::[3122423]
# 270::[1779359]
# 271::[4968934]
# 272::[1295375]
# 273::[153798]
# 274::[502416]
# 275::[2344174]
# 276::[2596373]
# 277::[2707203]
# 278::[5330155]
# 280::[5309512]

# %% [markdown]
# La cantidad de números mapeados a cada cubeta por la función _hash_ universal es

# %%
plt.bar(np.arange(thunivoa.colisiones.size), thunivoa.colisiones)
plt.xlabel('Cubeta')
plt.ylabel(u'Número de colisiones')
plt.show()

# %% [markdown]
# El número de colisiones totales que ocurrieron es

# %%
np.sum(thunivoa.colisiones[thunivoa.colisiones > 1] - 1)
# Out:
# 58.0

# %% [markdown]
# ## Funciones hash para cadenas
#
# Si deseamos almacenar cadenas de símbolos, es necesario convertirla a un solo número. La forma más simple es sumar sus códigos pero esto genera colisiones en palabras que usan los mismos símbolo. Una alternativa es la suma de los códigos multiplicados por un constante elevada a la posición
#
# $$
# f(s) = s_1 \cdot g^1 + s_2 \cdot g^2 + \cdots + s_d \cdot g^d
# $$
#
# Modificamos nuestra clase anterior para que cuando haya una colisión verifique si es la misma subcadena.

# %%
class THUnivCad(THUnivOA):
  def __init__(self, n_cubetas, a, b, primo, g):
    super().__init__(n_cubetas, a, b, primo)
    self.g = g
  
  def s2i(self, s):
    return sum([ord(c) * self.g**ord(c) for c in s])

  def insertar(self, s):
    x = int(self.s2i(s))
    cubeta = self.h(x)
    self.colisiones[cubeta] += 1
    
    llena = True
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if not self.tabla[ind]:
        self.tabla[ind].append(s)
        llena = False
        break

    if llena:
      print('Tabla llena')

  def buscar(self, s):
    x = self.s2i(s)
    cubeta = self.h(x)
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if self.tabla[ind][0] == s:
        return ind

    return -1

  def eliminar(self, s):
    x = self.s2i(s)
    cubeta = self.h(x)
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if self.tabla[ind][0] == s:
        self.tabla[ind].remove(s)
        return ind

    return -1

# %% [markdown]
# Veamos un ejemplo

# %%
nombres = ['blanca', 'juan', 'pedro', 'julia', 'serena', 'enrique', 'jose', 'alfonso', 'rodolfo', 'ignacio', 'gibran', 'mariana']
thucad = THUnivCad(281, a, b, 104729, 1.1)
for e in nombres:
  thucad.insertar(e)
print(thucad)
# Out:
# 2::['mariana']
# 4::['jose']
# 73::['blanca']
# 85::['julia']
# 88::['enrique']
# 104::['rodolfo']
# 117::['serena']
# 120::['juan']
# 163::['alfonso']
# 174::['pedro']
# 192::['gibran']
# 248::['ignacio']

# %% [markdown]
# Revisemos la cantidad de nombres mapeados a cada cubeta

# %%
plt.bar(np.arange(thucad.colisiones.size), thucad.colisiones)
plt.xlabel('Cubeta')
plt.ylabel(u'Número de colisiones')
plt.show()

# %% [markdown]
# ## Ejercicio
# Realiza lo siguiente:
# 1. Implementa una tabla que realice sondeo cuadrático. Elige un número primo grande para $m$ y $c_1 = c_2 = 1$ y prueba la tabla con el conjunto de 200 números.
#
# $$
# h(x, i) = (h'(x) + c_1 \cdot i + c_2 \cdot i^2)\mod{m}
# $$

# %%
class Hash_Cuadratica(TablaHash):
  # Definimos los nuevos parámetros
  def __init__(self, n_cubetas, c1, c2):
    super().__init__(n_cubetas)
    self.c1 = c1
    self.c2 = c2
    self.n_cubetas = n_cubetas
    self.colisiones = np.zeros(n_cubetas)

  def sl(self, cubeta, i):
    return ((cubeta+ self.c1*i + self.c2*i**2)%n_cubetas)

  def insertar(self, x):
    llena = True
    cubeta = self.h(x)  
    self.colisiones[cubeta] += 1
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if not self.tabla[ind]:
        self.tabla[ind].append(x)
        llena = False
        break

    if llena:
      print('Tabla llena')

  def buscar(self, x):
    cubeta = self.h(x)
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if self.tabla[ind][0] == x:
        return ind

    return -1

  def eliminar(self, x):
    cubeta = self.h(x)
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if self.tabla[ind][0] == x:
        self.tabla[ind].remove(x)
        return ind
        
    return -1

class HCuad_Mod(Hash_Cuadratica):
  def h(self, x):
    return x % self.n_cubetas

# %%
# Probemos con el ejemplo dado

cuad = HCuad_Mod(281, 1, 1)
for i, e in enumerate(conj):
  cuad.insertar(e)
print(cuad)
# Out:
# 0::[4513402]
# 1::[143843]
# 2::[189396]
# 5::[5330155]
# 6::[555543]
# 8::[821652]
# 11::[4968934]
# 14::[1956898]
# 17::[5309512]
# 19::[822787]
# 20::[812863]
# 21::[4090819]
# 22::[5231680]
# 23::[1574185]
# 24::[5193657]
# 25::[3710068]
# 27::[48078]
# 28::[4617139]
# 29::[3439750]
# 30::[41337]
# 31::[1720313]
# 32::[1242052]
# 33::[2978633]
# 34::[2292430]
# 35::[5600644]
# 36::[4024793]
# 37::[628628]
# 38::[4327719]
# 40::[2289897]
# 41::[2166551]
# 42::[1324114]
# 43::[337803]
# 44::[211637]
# 45::[347060]
# 46::[3454379]
# 47::[1650360]
# 48::[4154065]
# 49::[220632]
# 50::[2821569]
# 51::[621904]
# 52::[5387103]
# 55::[755102]
# 56::[1749269]
# 57::[1963123]
# 60::[4242879]
# 61::[57385]
# 63::[1917045]
# 64::[3817407]
# 65::[3839087]
# 66::[5603206]
# 67::[1779359]
# 68::[3777270]
# 69::[2742067]
# 70::[5643674]
# 71::[1435419]
# 72::[970365]
# 73::[892780]
# 74::[2344174]
# 76::[5130574]
# 79::[2707203]
# 80::[1885584]
# 82::[276586]
# 83::[1563848]
# 85::[2670428]
# 87::[4657381]
# 89::[2411350]
# 91::[153798]
# 94::[971230]
# 96::[310882]
# 99::[3021130]
# 100::[3287238]
# 101::[1952206]
# 102::[1271627]
# 104::[1493619]
# 105::[4791155]
# 106::[1594219]
# 107::[3656479]
# 108::[267339]
# 109::[4487958]
# 110::[3265611]
# 111::[1269950]
# 112::[250764]
# 114::[1198011]
# 115::[4606267]
# 116::[2633398]
# 117::[278869]
# 119::[3164458]
# 120::[337870]
# 121::[2057878]
# 122::[981934]
# 123::[2658102]
# 128::[4679039]
# 129::[2205686]
# 131::[462376]
# 132::[642217]
# 133::[5777493]
# 134::[3698656]
# 137::[726522]
# 138::[2084309]
# 139::[5804194]
# 140::[4724310]
# 141::[5089613]
# 142::[4991264]
# 143::[3561812]
# 144::[5449003]
# 145::[983083]
# 147::[2675548]
# 149::[545845]
# 151::[3218143]
# 153::[170158]
# 154::[3666361]
# 155::[4214310]
# 159::[3892571]
# 160::[3281116]
# 163::[3577574]
# 165::[175172]
# 167::[2449363]
# 172::[1319748]
# 174::[1978974]
# 175::[3165640]
# 176::[3450292]
# 177::[4224731]
# 178::[2379967]
# 180::[1956783]
# 182::[3241798]
# 183::[3800146]
# 184::[2631187]
# 185::[4223334]
# 186::[1819380]
# 188::[210093]
# 189::[4006681]
# 190::[2423528]
# 191::[5128439]
# 192::[3250238]
# 194::[2616304]
# 195::[192668]
# 197::[307330]
# 202::[3890085]
# 203::[3088955]
# 204::[1990246]
# 205::[2934686]
# 206::[1480231]
# 208::[1889646]
# 211::[4332107]
# 213::[2481724]
# 214::[3157530]
# 215::[4506048]
# 216::[933136]
# 217::[337698]
# 219::[5780389]
# 220::[2596373]
# 221::[4324249]
# 222::[4600734]
# 223::[708899]
# 225::[2294871]
# 227::[2080187]
# 229::[4813185]
# 231::[5844750]
# 232::[5777873]
# 233::[5493783]
# 234::[3122423]
# 235::[3140129]
# 236::[4941057]
# 237::[2929656]
# 239::[1410016]
# 240::[3109505]
# 241::[4999231]
# 242::[3921314]
# 243::[1823933]
# 245::[311029]
# 246::[1295375]
# 247::[1270367]
# 248::[2911970]
# 249::[1640163]
# 250::[2059699]
# 251::[102816]
# 252::[655544]
# 253::[3352009]
# 254::[593162]
# 255::[2693640]
# 257::[2600521]
# 258::[5290083]
# 259::[2597793]
# 260::[3300041]
# 261::[1832662]
# 263::[2787502]
# 264::[1627523]
# 265::[5219559]
# 266::[2247122]
# 267::[4674140]
# 268::[5048714]
# 269::[502416]
# 270::[3929210]
# 271::[5540461]
# 272::[3484389]
# 273::[5423286]
# 274::[4982966]
# 275::[4101169]
# 277::[3989592]
# 279::[3201993]

# %%
plt.bar(np.arange(cuad.colisiones.size), cuad.colisiones)
plt.xlabel('Cubeta')
plt.ylabel(u'Número de colisiones')
plt.show()

# %% [markdown]
# 2. Desarrolla un programa que cuente el número de ocurrencias de todas las subcadenas de longitud entre 5 a 10 (sin considerar espacios en blanco ni signos de admiración/interrogación ni caracteres especiales) usando funciones y tablas _hash_. Prueba este programa en la base de datos de _20 newsgroups_.

# %%
# primero vamos a descargar los datos.

from sklearn.datasets import fetch_20newsgroups
newsg = fetch_20newsgroups()

# %%
# Vamos a juntar los registros
texto = ' '.join(newsg.data)

# Ahora vamos a sepatrarlos de forma que sea palabra por palabra
palabras = texto.split()

# %%
# Vamos a eliminar primero las mayusculas por medio de lower(), pero solo 
# a aquellas palabras que sean lafanumericas, pues deseamos descartar 
# plabras con caracteres especiales

palabras = [d.lower() for d in palabras if d.isalnum()]

# Ahora filtremos las palabras mayor a 5 y menor a 10

palabras = [p for p in palabras if len(p) >= 5 and len(p) <= 10]

# %%
palabras
# Out:
# ['university',
#  'college',
#  'wondering',
#  'anyone',
#  'there',
#  'could',
#  'enlighten',
#  'other',
#  'sports',
#  'looked',
#  'early',
#  'called',
#  'doors',
#  'really',
#  'front',
#  'bumper',
#  'separate',
#  'anyone',
#  'tellme',
#  'model',
#  'engine',
#  'years',
#  'where',
#  'whatever',
#  'funky',
#  'looking',
#  'please',
#  'brought',
#  'lerxst',
#  'clock',
#  'final',
#  'final',
#  'clock',
#  'reports',
#  'university',
#  'washington',
#  'number',
#  'brave',
#  'souls',
#  'upgraded',
#  'their',
#  'clock',
#  'oscillator',
#  'shared',
#  'their',
#  'please',
#  'brief',
#  'message',
#  'detailing',
#  'speed',
#  'rated',
#  'cards',
#  'usage',
#  'floppy',
#  'floppies',
#  'especially',
#  'please',
#  'network',
#  'knowledge',
#  'clock',
#  'upgrade',
#  'answered',
#  'purdue',
#  'university',
#  'computer',
#  'network',
#  'finally',
#  'ghost',
#  'weekend',
#  'after',
#  'starting',
#  'market',
#  'machine',
#  'sooner',
#  'intended',
#  'looking',
#  'picking',
#  'powerbook',
#  'maybe',
#  'bunch',
#  'questions',
#  'somebody',
#  'anybody',
#  'round',
#  'powerbook',
#  'heard',
#  'supposed',
#  'appearence',
#  'heard',
#  'anymore',
#  'since',
#  'access',
#  'wondering',
#  'anybody',
#  'there',
#  'anybody',
#  'heard',
#  'rumors',
#  'about',
#  'price',
#  'drops',
#  'powerbook',
#  'through',
#  'impression',
#  'display',
#  'could',
#  'probably',
#  'swing',
#  'rather',
#  'really',
#  'display',
#  'looks',
#  'great',
#  'really',
#  'could',
#  'solicit',
#  'opinions',
#  'people',
#  'worth',
#  'taking',
#  'money',
#  'active',
#  'realize',
#  'subjective',
#  'played',
#  'around',
#  'machines',
#  'computer',
#  'store',
#  'breifly',
#  'figured',
#  'opinions',
#  'somebody',
#  'actually',
#  'machine',
#  'daily',
#  'might',
#  'prove',
#  'hellcats',
#  'thanks',
#  'bunch',
#  'advance',
#  'could',
#  'summary',
#  'reading',
#  'premium',
#  'finals',
#  'around',
#  'willis',
#  'purdue',
#  'electrical',
#  'dangerous',
#  'enemies',
#  'truth',
#  'nietzsche',
#  'weitek',
#  'p9000',
#  'harris',
#  'computer',
#  'systems',
#  'division',
#  'world',
#  'robert',
#  'kyanko',
#  'writes',
#  'article',
#  'anyone',
#  'about',
#  'weitek',
#  'p9000',
#  'graphics',
#  'stuff',
#  'looks',
#  'pretty',
#  'command',
#  'requires',
#  'about',
#  'green',
#  'harris',
#  'computer',
#  'systems',
#  'division',
#  'thing',
#  'really',
#  'scares',
#  'person',
#  'sense',
#  'jonathan',
#  'winters',
#  'shuttle',
#  'launch',
#  'question',
#  'article',
#  'article',
#  'caution',
#  'warning',
#  'verify',
#  'unexpected',
#  'wondering',
#  'might',
#  'sorry',
#  'really',
#  'parity',
#  'errors',
#  'memory',
#  'previously',
#  'known',
#  'conditions',
#  'already',
#  'about',
#  'curious',
#  'meaning',
#  'quote',
#  'basically',
#  'known',
#  'warning',
#  'system',
#  'software',
#  'things',
#  'checked',
#  'right',
#  'values',
#  'because',
#  'after',
#  'rather',
#  'possibly',
#  'introduce',
#  'warning',
#  'before',
#  'ignore',
#  'jonathan',
#  'rewording',
#  'second',
#  'amendment',
#  'article',
#  'article',
#  'article',
#  'article',
#  'lawrence',
#  'massive',
#  'power',
#  'modern',
#  'makes',
#  'accidental',
#  'crimial',
#  'usage',
#  'these',
#  'weapons',
#  'weapons',
#  'control',
#  'government',
#  'individual',
#  'access',
#  'would',
#  'result',
#  'needless',
#  'deaths',
#  'makes',
#  'right',
#  'people',
#  'modern',
#  'weapons',
#  'stating',
#  'where',
#  'coming',
#  'needless',
#  'every',
#  'believe',
#  'should',
#  'right',
#  'weapons',
#  'believe',
#  'would',
#  'support',
#  'right',
#  'nuclear',
#  'biological',
#  'nerve',
#  'cannot',
#  'agree',
#  'keeping',
#  'weapons',
#  'hands',
#  'there',
#  'blank',
#  'rigidly',
#  'defined',
#  'foxvog',
#  'means',
#  'sarah',
#  'brady',
#  'means',
#  'sweeper',
#  'shotguns',
#  'doubt',
#  'using',
#  'quote',
#  'allegedly',
#  'rutledge',
#  'thousands',
#  'people',
#  'killed',
#  'number',
#  'easily',
#  'reduced',
#  'putting',
#  'reasonable',
#  'rutledge',
#  'article',
#  'presenting',
#  'first',
#  'argument',
#  'about',
#  'weapons',
#  'commonly',
#  'switching',
#  'other',
#  'first',
#  'point',
#  'evidently',
#  'weapons',
#  'should',
#  'later',
#  'analysis',
#  'given',
#  'consider',
#  'another',
#  'believe',
#  'speak',
#  'write',
#  'today',
#  'special',
#  'foxvog',
#  'manning',
#  'brain',
#  'tumor',
#  'treatment',
#  'university',
#  'chicago',
#  'there',
#  'people',
#  'responded',
#  'request',
#  'treatment',
#  'through',
#  'thank',
#  'directly',
#  'because',
#  'probs',
#  'thought',
#  'publicly',
#  'thank',
#  'instead',
#  'trying',
#  'delete',
#  'mexico',
#  'state',
#  'world',
#  'article',
#  'magazine',
#  'april',
#  'twice',
#  'fasst',
#  'faster',
#  'support',
#  'devices',
#  'acceptance',
#  'stalled',
#  'problems',
#  'magazine',
#  'writers',
#  'stupid',
#  'statements',
#  'where',
#  'those',
#  'actual',
#  'which',
#  'should',
#  'convince',
#  'anyone',
#  'ranges',
#  'ranges',
#  'ranges',
#  'always',
#  'there',
#  'shows',
#  'about',
#  'controler',
#  'range',
#  'indeed',
#  'right',
#  'about',
#  'controller',
#  'burst',
#  'increase',
#  'quadra',
#  'version',
#  'burst',
#  'burst',
#  'burst',
#  'twice',
#  'correct',
#  'controller',
#  'reach',
#  'which',
#  'indeed',
#  'faster',
#  'these',
#  'facts',
#  'posted',
#  'newsgroup',
#  'sheet',
#  'should',
#  'still',
#  'problem',
#  'inconsiant',
#  'about',
#  'though',
#  'documented',
#  'quadra',
#  'apple',
#  'burst',
#  'maximum',
#  'quadra',
#  'which',
#  'seems',
#  'interface',
#  'think',
#  'maybe',
#  'interface',
#  'driven',
#  'machine',
#  'controller',
#  'faster',
#  'article',
#  'because',
#  'understand',
#  'going',
#  'reference',
#  'controller',
#  'university',
#  'northern',
#  'downloaded',
#  'several',
#  'icons',
#  'figure',
#  'change',
#  'would',
#  'please',
#  'sigma',
#  'designs',
#  'double',
#  'university',
#  'illinois',
#  'urbana',
#  'looking',
#  'about',
#  'sigma',
#  'designs',
#  'double',
#  'figure',
#  'hardware',
#  'board',
#  'works',
#  'about',
#  'would',
#  'board',
#  'licensing',
#  'problem',
#  'owners',
#  'writing',
#  'please',
#  'correct',
#  'using',
#  'problems',
#  'icons',
#  'being',
#  'whether',
#  'fault',
#  'something',
#  'decompress',
#  'troubled',
#  'recompress',
#  'without',
#  'usually',
#  'because',
#  'above',
#  'mentioned',
#  'licensing',
#  'freeware',
#  'expansion',
#  'utility',
#  'expand',
#  'decompress',
#  'unless',
#  'board',
#  'since',
#  'product',
#  'seems',
#  'unlikely',
#  'holes',
#  'related',
#  'board',
#  'which',
#  'makes',
#  'reluctant',
#  'product',
#  'since',
#  'being',
#  'computing',
#  'services',
#  'computrac',
#  'richardson',
#  'ducati',
#  '900gts',
#  'model',
#  'paint',
#  'faded',
#  'leaks',
#  'trans',
#  'thinking',
#  'opinions',
#  'please',
#  'email',
#  'would',
#  'stable',
#  'myself',
#  'therefore',
#  'question',
#  'those',
#  'popular',
#  'morality',
#  'world',
#  'camtec',
#  'england',
#  'bangkok',
#  'article',
#  'previous',
#  'think',
#  'wrong',
#  'different',
#  'posting',
#  'again',
#  'explaining',
#  'thought',
#  'could',
#  'moral',
#  'overlooked',
#  'saying',
#  'being',
#  'morality',
#  'pretty',
#  'understand',
#  'jewish',
#  'believe',
#  'covenant',
#  'between',
#  'patriarchs',
#  'moral',
#  'follow',
#  'could',
#  'decide',
#  'where',
#  'boundaries',
#  'understand',
#  'sadducees',
#  'believed',
#  'torah',
#  'whereas',
#  'pharisees',
#  'ancestors',
#  'modern',
#  'believed',
#  'torah',
#  'available',
#  'required',
#  'morality',
#  'nuances',
#  'essence',
#  'biblical',
#  'morality',
#  'interface',
#  'between',
#  'indicate',
#  'anything',
#  'about',
#  'outside',
#  'first',
#  'thing',
#  'comes',
#  'supposed',
#  'created',
#  'there',
#  'argument',
#  'committed',
#  'whatever',
#  'follows',
#  'trying',
#  'supposed',
#  'would',
#  'pressed',
#  'trouble',
#  'really',
#  'heard',
#  'number',
#  'different',
#  'opinions',
#  'still',
#  'rather',
#  'upsets',
#  'apple',
#  'wants',
#  'script',
#  'shaky',
#  'foundation',
#  'metaphors',
#  'living',
#  'little',
#  'about',
#  'jesus',
#  'recorded',
#  'utterances',
#  'narratives',
#  'small',
#  'references',
#  'revelation',
#  'christ',
#  'attempt',
#  'debunk',
#  'point',
#  'trying',
#  'really',
#  'bible',
#  'guess',
#  'where',
#  'faith',
#  'relevation',
#  'comes',
#  'inherent',
#  'there',
#  'multiple',
#  'moral',
#  'codes',
#  'there',
#  'moral',
#  'think',
#  'there',
#  'absolute',
#  'moral',
#  'there',
#  'multiple',
#  'moral',
#  'multiple',
#  'moral',
#  'codes',
#  'founded',
#  'absolute',
#  'moral',
#  'parent',
#  'child',
#  'never',
#  'child',
#  'assume',
#  'parent',
#  'never',
#  'swears',
#  'simply',
#  'because',
#  'parent',
#  'child',
#  'parent',
#  'swear',
#  'trooper',
#  'there',
#  'child',
#  'disobeys',
#  'parent',
#  'swear',
#  'front',
#  'children',
#  'quite',
#  'happy',
#  'swear',
#  'front',
#  'analogy',
#  'quite',
#  'water',
#  'because',
#  'child',
#  'knows',
#  'parent',
#  'parent',
#  'later',
#  'young',
#  'child',
#  'considers',
#  'directive',
#  'absolute',
#  'until',
#  'older',
#  'learns',
#  'morality',
#  'where',
#  'fishes',
#  'clearness',
#  'hewlett',
#  'cerkoney',
#  'cerkoney',
#  'hewlett',
#  'packard',
#  'harmony',
#  '80525',
#  'space',
#  'station',
#  'lewis',
#  'research',
#  'center',
#  'world',
#  'vnews',
#  'article',
#  'option',
#  'redesign',
#  'proposed',
#  'design',
#  'committee',
#  'crystal',
#  'reports',
#  'warmly',
#  'rumors',
#  'design',
#  'based',
#  'wingless',
#  'space',
#  'shuttle',
#  'orbiter',
#  'options',
#  'deleted',
#  'redesign',
#  'options',
#  'edition',
#  'times',
#  'reports',
#  'panel',
#  'redesign',
#  'proposals',
#  'using',
#  'external',
#  'tanks',
#  'launching',
#  'space',
#  'building',
#  'around',
#  'existing',
#  'space',
#  'shuttle',
#  'wings',
#  'there',
#  'three',
#  'options',
#  'being',
#  'presented',
#  'advisory',
#  'panel',
#  'meeting',
#  'yesterday',
#  'reported',
#  'option',
#  'modular',
#  'approach',
#  'option',
#  'being',
#  'studied',
#  'there',
#  'redesign',
#  'teams',
#  'supporting',
#  'redesign',
#  'crystal',
#  'reston',
#  'folks',
#  'these',
#  'helping',
#  'respective',
#  'teams',
#  'their',
#  'redesign',
#  'features',
#  'option',
#  'modular',
#  'developed',
#  'lockheed',
#  'qualified',
#  'provides',
#  'lockheed',
#  'developed',
#  'station',
#  'obtained',
#  'shuttle',
#  'solar',
#  'arrays',
#  'provide',
#  'vehicle',
#  'flies',
#  'optimize',
#  'missions',
#  'would',
#  'utilize',
#  'vehilce',
#  'power',
#  'source',
#  'human',
#  'tended',
#  'capability',
#  'opposed',
#  'sexist',
#  'achieved',
#  'addition',
#  'common',
#  'modified',
#  'version',
#  'existing',
#  'module',
#  'ports',
#  'added',
#  'taking',
#  'place',
#  'nodes',
#  'shuttle',
#  'docked',
#  'station',
#  'orbiter',
#  'would',
#  'provide',
#  'human',
#  'nasda',
#  'another',
#  'power',
#  'permanent',
#  'human',
#  'presence',
#  'power',
#  'habitation',
#  'return',
#  'option',
#  'space',
#  'station',
#  'freedom',
#  'derived',
#  'option',
#  'based',
#  'option',
#  'looks',
#  'existing',
#  'which',
#  'option',
#  'assumes',
#  'external',
#  'available',
#  'assembly',
#  'flights',
#  'option',
#  'number',
#  'flights',
#  'computed',
#  'options',
#  'occurs',
#  'initial',
#  'research',
#  'capability',
#  'reached',
#  'after',
#  'power',
#  'vehicle',
#  'capability',
#  'adopted',
#  'achieved',
#  'after',
#  'solar',
#  'power',
#  'module',
#  'provides',
#  'permanent',
#  'human',
#  'presence',
#  'capability',
#  'occurs',
#  'after',
#  'keeping',
#  'orbiter',
#  'sometimes',
#  'there',
#  'would',
#  'orbiters',
#  'second',
#  'comes',
#  'logistics',
#  'fault',
#  'tolerance',
#  'achieved',
#  'after',
#  'addition',
#  'power',
#  'another',
#  'thermal',
#  'control',
#  'system',
#  'propulsion',
#  'after',
#  'habitation',
#  'added',
#  'finish',
#  'assembly',
#  'systems',
#  'currently',
#  'exception',
#  'management',
#  'which',
#  'major',
#  'option',
#  'single',
#  'launch',
#  'diameter',
#  'cylinder',
#  'space',
#  'shuttle',
#  'engines',
#  'attached',
#  'regular',
#  'shuttle',
#  'external',
#  'regular',
#  'solid',
#  'rocket',
#  'launch',
#  'features',
#  'complete',
#  'ground',
#  'checkout',
#  'mounted',
#  'fixed',
#  'solar',
#  'panels',
#  'mounted',
#  'radiators',
#  'protection',
#  'against',
#  'orbital',
#  'centerline',
#  'docking',
#  'ports',
#  'berthing',
#  'ports',
#  'single',
#  'cubic',
#  'volume',
#  'center',
#  'passageway',
#  'between',
#  'floors',
#  'power',
#  'graceful',
#  'failures',
#  'power',
#  'thermal',
#  'control',
#  'support',
#  'increased',
#  'module',
#  'moving',
#  'moving',
#  'reduced',
#  'things',
#  'forsale',
#  'behalf',
#  'moving',
#  'black',
#  'decker',
#  'duster',
#  'purchased',
#  'cassette',
#  'portable',
#  'graphics',
#  'speed',
#  'seems',
#  'treble',
#  'purchased',
#  '1200x',
#  'includes',
#  'purchased',
#  'dryer',
#  'purchased',
#  'speed',
#  'brand',
#  'never',
#  'pusle',
#  'matic',
#  'speeds',
#  'years',
#  'purchased',
#  'binoculars',
#  ...]

# %% [markdown]
# Para generar el conteo vamos a tomar como referencia la función vista en clase:

# %%
class THUnivCad(THUnivOA):
  def __init__(self, n_cubetas, a, b, primo, g):
    super().__init__(n_cubetas, a, b, primo)
    self.g = g
  
  def s2i(self, s):
    return sum([ord(c) * self.g**i for i, c in enumerate(s)])

  def insertar(self, s):
    x = int(self.s2i(s))
    cubeta = self.h(x)
    #self.colisiones[cubeta] += 1
    
    llena = True
    cnt = 1
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if not self.tabla[ind]:
        self.tabla[ind].append((s, cnt))
        llena = False
        break
      if self.tabla[ind]:
        #if s == self.tabla[ind][0]:
          #self.tabla[ind][0][1] = self.tabla[ind][0]
          self.tabla[ind][0] = (self.tabla[ind][0][0], self.tabla[ind][0][1] + 1)
          llena = False
          break


    if llena:
      print('Tabla llena')

    #if llena:
     # print('Tabla llena')

  def buscar(self, s):
    x = self.s2i(s)
    cubeta = self.h(x)
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if self.tabla[ind][0] == s:
        return ind

    return -1

  def eliminar(self, s):
    x = self.s2i(s)
    cubeta = self.h(x)
    for i in range(self.n_cubetas):
      ind = self.sl(cubeta, i)
      if self.tabla[ind][0] == s:
        self.tabla[ind].remove(s)
        return ind

    return -1

# %%
thucad = THUnivCad(1000003, a, b, 104729, 1.1)
for e in palabras:
  thucad.insertar(e)
print(thucad)
# Out:
# 62::[('homicide', 251)]
# 135::[('accidental', 124)]
# 201::[('brady', 2499)]
# 413::[('cb400t', 20)]
# 486::[('honesty', 199)]
# 559::[('sulfurous', 1)]
# 625::[('2000cc', 2)]
# 698::[('keeping', 1544)]
# 771::[('logistics', 648)]
# 837::[('73m550', 2)]
# 910::[('cabbage', 2)]
# 983::[('aggregate', 77)]
# 1049::[('583905', 14)]
# 1122::[('shorty', 105)]
# 1261::[('0a000', 1)]
# 1334::[('coming', 3715)]
# 1407::[('printout', 23)]
# 1480::[('assumption', 332)]
# 1546::[('87f350800', 4)]
# 1619::[('athletes', 716)]
# 1692::[('boundaries', 251)]
# 1758::[('sorts', 220)]
# 1831::[('ballance', 6)]
# 1904::[('challenged', 129)]
# 1970::[('email', 1822)]
# 2182::[('hc1dt', 8)]
# 2255::[('shuttle', 1811)]
# 2328::[('nestorius', 126)]
# 2394::[('ls12i', 21)]
# 2467::[('offered', 758)]
# 2540::[('nietzsche', 814)]
# 2606::[('512kb', 8)]
# 2679::[('8oox6oo', 6)]
# 2752::[('checkered', 47)]
# 2818::[('127223', 11)]
# 2891::[('system', 2517)]
# 3030::[('98195', 11)]
# 3037::[('oportunity', 1)]
# 3103::[('decker', 577)]
# 3176::[('sympathy', 202)]
# 3249::[('impression', 528)]
# 3315::[('kb7gbq', 1)]
# 3388::[('separate', 1342)]
# 3461::[('inadequate', 197)]
# 3527::[('group', 2286)]
# 3600::[('embedded', 23)]
# 3739::[('famed', 69)]
# 3951::[('48khz', 5)]
# 4024::[('library', 1335)]
# 4097::[('terrorism', 394)]
# 4163::[('dn2500', 14)]
# 4236::[('panache', 186)]
# 4309::[('basically', 1249)]
# 4375::[('sr500', 6)]
# 4448::[('32mbyte', 1)]
# 4521::[('braindead', 14)]
# 4660::[('almost', 2656)]
# 4799::[('94025', 40)]
# 4806::[('interrupts', 28)]
# 4872::[('called', 1256)]
# 4945::[('imprison', 692)]
# 5018::[('decompress', 468)]
# 5084::[('hicn610', 4)]
# 5157::[('japanese', 974)]
# 5230::[('california', 733)]
# 5296::[('using', 3955)]
# 5369::[('compass7', 2)]
# 5508::[('bbddd', 39)]
# 5581::[('support', 1069)]
# 5654::[('verrrrrry', 1)]
# 5720::[('x11rn', 2)]
# 5727::[('victoriaõs', 2)]
# 5793::[('despite', 2376)]
# 5866::[('evidently', 651)]
# 5932::[('300ts', 1)]
# 6005::[('bandage', 6)]
# 6078::[('tolerance', 483)]
# 6144::[('es300', 4)]
# 6217::[('ruuttu', 9)]
# 6290::[('find2perl', 1)]
# 6356::[('r3000', 7)]
# 6429::[('anyone', 6695)]
# 6502::[('16megabit', 1)]
# 6568::[('22102', 26)]
# 6575::[('institutes', 23)]
# 6641::[('bbbbig', 62)]
# 6714::[('existing', 579)]
# 6787::[('manzanillo', 166)]
# 6853::[('rusty', 11)]
# 6926::[('carnegie', 566)]
# 6999::[('appearence', 31)]
# 7065::[('there', 15553)]
# 7138::[('tms320c3x', 1)]
# 7277::[('aa02784', 2)]
# 7350::[('destroy', 557)]
# 7423::[('outstrips', 12)]
# 7489::[('mx47i', 5)]
# 7562::[('picking', 940)]
# 7635::[('exception', 785)]
# 7701::[('263rd', 1)]
# 7774::[('maxen386', 2)]
# 7847::[('advantage', 306)]
# 7913::[('434359', 9)]
# 7986::[('supply', 316)]
# 8198::[('deaths', 3528)]
# 8271::[('property', 164)]
# 8344::[('constitute', 240)]
# 8410::[('10000000b', 2)]
# 8483::[('appendix', 792)]
# 8556::[('subcompact', 283)]
# 8622::[('spout', 23)]
# 8695::[('biblical', 281)]
# 8768::[('despicable', 9)]
# 8834::[('final', 3055)]
# 9046::[('kdx200', 9)]
# 9119::[('minutes', 1328)]
# 9192::[('authority', 733)]
# 9258::[('3958784', 5)]
# 9331::[('college', 1815)]
# 9404::[('something', 2708)]
# 9470::[('340mb', 17)]
# 9543::[('tophat1', 2)]
# 9616::[('intifadah', 30)]
# 9682::[('680060', 14)]
# 9755::[('sexist', 361)]
# 9894::[('94577', 1)]
# 9967::[('killed', 1234)]
# 10040::[('security', 763)]
# 10113::[('submission', 109)]
# 10179::[('wa1lbk', 1)]
# 10252::[('addition', 1096)]
# 10325::[('management', 375)]
# 10391::[('funky', 800)]
# 10464::[('aspi4dos', 17)]
# 10537::[('marblehead', 1)]
# 10603::[('black', 873)]
# 10676::[('krustys', 1)]
# 10815::[('00900001', 6)]
# 10888::[('anymore', 2970)]
# 10961::[('octopuses', 318)]
# 11027::[('gs1000', 4)]
# 11100::[('medical', 604)]
# 11173::[('mentioned', 1057)]
# 11239::[('vt100', 8)]
# 11312::[('crchh435', 2)]
# 11385::[('debatable', 4)]
# 11451::[('1542a', 9)]
# 11524::[('verify', 1694)]
# 11663::[('80525', 108)]
# 11670::[('previously', 124)]
# 11736::[('indeed', 1015)]
# 11809::[('contents', 412)]
# 11882::[('everything', 885)]
# 11948::[('st3283n', 2)]
# 12021::[('increase', 1703)]
# 12094::[('considered', 588)]
# 12160::[('vijay', 3138)]
# 12233::[('2channel', 2)]
# 12372::[('srx250', 9)]
# 12445::[('surplus', 47)]
# 12518::[('volvovitz', 1)]
# 12584::[('1500mb', 14)]
# 12657::[('edition', 3059)]
# 12730::[('ancestors', 906)]
# 12796::[('bj10e', 3)]
# 12869::[('damaged', 142)]
# 12942::[('confirmed', 378)]
# 13008::[('ap153', 5)]
# 13220::[('t2000', 3)]
# 13293::[('thanks', 3908)]
# 13432::[('10601', 14)]
# 13439::[('cryptology', 37)]
# 13505::[('backed', 53)]
# 13578::[('congress', 695)]
# 13651::[('respective', 320)]
# 13717::[('k5w1zd', 1)]
# 13790::[('accessed', 154)]
# 13863::[('accessible', 165)]
# 13929::[('these', 5505)]
# 14141::[('74xxx', 4)]
# 14214::[('reports', 295)]
# 14287::[('spurrious', 2)]
# 14353::[('zzr11', 11)]
# 14426::[('figured', 1404)]
# 14499::[('compilers', 540)]
# 14565::[('500th', 5)]
# 14711::[('reference', 639)]
# 14777::[('bj200', 33)]
# 14850::[('upupup', 8)]
# 15062::[('active', 2072)]
# 15135::[('symptoms', 103)]
# 15208::[('soderstrom', 67)]
# 15274::[('00000001b', 15)]
# 15347::[('computed', 770)]
# 15420::[('subscriber', 372)]
# 15486::[('tours', 46)]
# 15559::[('affected', 138)]
# 15632::[('applicable', 67)]
# 15698::[('range', 1016)]
# 15771::[('aslslc120', 2)]
# 15844::[('starchart2', 1)]
# 15910::[('bc546b', 3)]
# 15983::[('toolbox', 857)]
# 16056::[('astronomy', 147)]
# 16122::[('vs2000', 7)]
# 16195::[('imagine', 913)]
# 16268::[('clearness', 589)]
# 16334::[('640kb', 19)]
# 16480::[('impedance', 103)]
# 16546::[('40x25', 5)]
# 16619::[('groups', 1017)]
# 16758::[('27599', 6)]
# 16831::[('recall', 1093)]
# 16904::[('strictly', 294)]
# 16977::[('simplicity', 585)]
# 17043::[('drive7', 1)]
# 17116::[('berthing', 1918)]
# 17189::[('legitimate', 435)]
# 17255::[('tools', 887)]
# 17328::[('haaaaate', 1)]
# 17401::[('defineable', 1)]
# 17467::[('bible', 973)]
# 17679::[('66mhz', 14)]
# 17752::[('company', 2355)]
# 17825::[('continuum', 91)]
# 17891::[('7629353', 6)]
# 17964::[('behanna', 310)]
# 18037::[('defensive', 785)]
# 18103::[('xl250', 8)]
# 18249::[('crackable', 8)]
# 18315::[('7213a', 19)]
# 18388::[('follow', 1813)]
# 18527::[('95062', 27)]
# 18534::[('supersport', 4)]
# 18600::[('bombed', 857)]
# 18673::[('possibly', 1167)]
# 18746::[('conditions', 958)]
# 18885::[('extended', 433)]
# 18958::[('appreciate', 720)]
# 19024::[('years', 5877)]
# 19097::[('compass8', 2)]
# 19236::[('added', 195)]
# 19309::[('mystery', 73)]
# 19448::[('85mph', 5)]
# 19521::[('looking', 2502)]
# 19594::[('situation', 606)]
# 19660::[('386dx', 16)]
# 19733::[('grabbed', 31)]
# 19806::[('clearasil', 554)]
# 19872::[('hp500', 7)]
# 19945::[('crchh410', 11)]
# 20084::[('t1200', 4)]
# 20157::[('common', 2742)]
# 20296::[('14400', 36)]
# 20303::[('instructor', 21)]
# 20369::[('vfr750f', 21)]
# 20442::[('supposed', 1865)]
# 20515::[('foundation', 580)]
# 20581::[('yozzo', 4)]
# 20654::[('launched', 1206)]
# 20727::[('biological', 94)]
# 20793::[('daily', 5463)]
# 21005::[('n5gjm', 14)]
# 21078::[('century', 176)]
# 21151::[('printouts', 1)]
# 21217::[('xl5580', 4)]
# 21290::[('already', 1999)]
# 21363::[('reluctant', 1514)]
# 21429::[('16mx1', 1)]
# 21575::[('residence', 219)]
# 21641::[('1970s', 14)]
# 21714::[('stormy', 11)]
# 21853::[('0c000', 1)]
# 21926::[('method', 2304)]
# 21999::[('industry', 168)]
# 22072::[('philosophy', 107)]
# 22138::[('00010100b', 36)]
# 22211::[('external', 1062)]
# 22284::[('liberation', 328)]
# 22350::[('1024x768', 104)]
# 22423::[('advanced', 214)]
# 22496::[('campaigned', 29)]
# 22562::[('tific', 1102)]
# 22774::[('duo210', 6)]
# 22847::[('statute', 673)]
# 22920::[('purposely', 107)]
# 22986::[('rs6000', 6)]
# 23059::[('zealand', 1043)]
# 23132::[('computrac', 642)]
# 23198::[('170mb', 12)]
# 23271::[('pdb2scn', 1)]
# 23344::[('proceeded', 344)]
# 23410::[('3401p', 17)]
# 23483::[('upsets', 555)]
# 23622::[('39994', 8)]
# 23695::[('shared', 1595)]
# 23768::[('previous', 600)]
# 23841::[('oppressive', 329)]
# 23907::[('2200lbs', 5)]
# 23980::[('entitled', 1118)]
# 24053::[('discovered', 220)]
# 24119::[('worth', 1772)]
# 24192::[('balanced', 215)]
# 24265::[('combocache', 3)]
# 24331::[('based', 1511)]
# 24543::[('3000gt', 1)]
# 24616::[('numbers', 1257)]
# 24689::[('institute', 953)]
# 24755::[('4916384', 31)]
# 24828::[('defined', 442)]
# 24901::[('enlighten', 2042)]
# 24967::[('600cc', 10)]
# 25040::[('ds1489an', 9)]
# 25113::[('agreeable', 10)]
# 25179::[('1742a', 29)]
# 25186::[('drwxrwxrwx', 1)]
# 25252::[('person', 2606)]
# 25391::[('95008', 86)]
# 25398::[('vigorously', 5)]
# 25464::[('cancel', 363)]
# 25537::[('products', 929)]
# 25610::[('narratives', 1173)]
# 25676::[('1000ff08', 1)]
# 25749::[('approach', 626)]
# 25822::[('spacecraft', 391)]
# 25888::[('round', 1235)]
# 26100::[('ahead', 174)]
# 26173::[('extropy', 20)]
# 26312::[('00000000', 5)]
# 26385::[('designs', 1683)]
# 26458::[('hopefully', 230)]
# 26524::[('486dx', 7)]
# 26597::[('cadence', 9)]
# 26670::[('purchased', 634)]
# 26736::[('pg502', 3)]
# 26809::[('luxury', 25)]
# 26948::[('3c505', 2)]
# 27021::[('should', 7145)]
# 27160::[('56000', 36)]
# 27167::[('autonomous', 46)]
# 27233::[('wa3wbu', 10)]
# 27306::[('strength', 854)]
# 27379::[('binoculars', 630)]
# 27445::[('st9077a', 2)]
# 27518::[('specific', 722)]
# 27591::[('remembered', 68)]
# 27657::[('where', 5564)]
# 27730::[('chem2scn', 3)]
# 27869::[('n1hcv', 5)]
# 27942::[('murrays', 49)]
# 28015::[('mykotronx', 36)]
# 28081::[('r003050', 1)]
# 28154::[('jasmine', 2120)]
# 28227::[('powerbook', 1149)]
# 28293::[('190hp', 1)]
# 28439::[('qualified', 236)]
# 28505::[('1980s', 7)]
# 28578::[('soltys', 6)]
# 28790::[('tellme', 1366)]
# 28863::[('tomorrow', 56)]
# 28936::[('revolution', 208)]
# 29002::[('ka1krp', 54)]
# 29075::[('anything', 2435)]
# 29148::[('sufficient', 680)]
# 29214::[('worst', 204)]
# 29287::[('declared', 137)]
# 29360::[('acceptance', 69)]
# 29426::[('clock', 2393)]
# 29638::[('8000hz', 7)]
# 29711::[('trooper', 241)]
# 29784::[('obviously', 313)]
# 29850::[('mc1488', 6)]
# 29923::[('vehilce', 558)]
# 29996::[('pantheism', 558)]
# 30062::[('273ci', 26)]
# 30208::[('maldanado', 14)]
# 30274::[('222833', 10)]
# 30347::[('subtly', 417)]
# 30486::[('18789', 4)]
# 30559::[('delete', 1292)]
# 30632::[('plymouth', 116)]
# 30705::[('components', 230)]
# 30844::[('answered', 1049)]
# 30917::[('documented', 289)]
# 30983::[('venus', 594)]
# 31056::[('baffeled', 1)]
# 31129::[('magliacane', 1)]
# 31195::[('cabin', 337)]
# 31407::[('640x200', 6)]
# 31480::[('brought', 3406)]
# 31553::[('consensus', 87)]
# 31619::[('2ef221', 13)]
# 31692::[('chicago', 441)]
# 31765::[('amendment', 740)]
# 31831::[('it175', 33)]
# 31904::[('12month', 2)]
# 31977::[('breakable', 15)]
# 32043::[('8060b', 1)]
# 32116::[('foxvog', 3173)]
# 32255::[('21738', 62)]
# 32262::[('synonomous', 2)]
# 32328::[('docked', 568)]
# 32401::[('question', 1760)]
# 32474::[('washington', 862)]
# 32540::[('wb3eah', 12)]
# 32613::[('standard', 1593)]
# 32686::[('inevitable', 143)]
# 32752::[('still', 4113)]
# 32825::[('16550uart', 2)]
# 32898::[('backhanded', 3)]
# 32964::[('faded', 48)]
# 33037::[('gurvitz', 12)]
# 33176::[('diff3', 5)]
# 33249::[('breifly', 5170)]
# 33322::[('rawlinson', 256)]
# 33388::[('mc05a', 4)]
# 33461::[('baffled', 14)]
# 33534::[('developed', 640)]
# 33600::[('ft500', 3)]
# 33673::[('trusty', 4)]
# 33812::[('p9000', 22)]
# 33885::[('really', 7368)]
# 34024::[('02115', 17)]
# 34031::[('continuous', 72)]
# 34097::[('wa7kgx', 21)]
# 34170::[('analysis', 838)]
# 34243::[('inconsiant', 254)]
# 34309::[('fuzzy', 27)]
# 34382::[('indicate', 1158)]
# 34455::[('exacerbate', 234)]
# 34521::[('later', 3541)]
# 34733::[('babba', 2)]
# 34806::[('systems', 1672)]
# 34879::[('rumkovsky', 4)]
# 34945::[('m35ko', 7)]
# 35018::[('dealers', 1130)]
# 35091::[('treatment', 474)]
# 35157::[('178mg', 6)]
# 35303::[('peaceably', 273)]
# 35369::[('cb650', 13)]
# 35442::[('stunts', 5)]
# 35581::[('0e000', 1)]
# 35654::[('blocks', 1855)]
# 35727::[('yorktown', 14)]
# 35800::[('protectors', 17)]
# 35866::[('cccccc', 86)]
# 35939::[('covenant', 1781)]
# 36012::[('overlooked', 455)]
# 36078::[('surly', 19)]
# 36151::[('dedicate', 21)]
# 36224::[('confidence', 40)]
# 36290::[('speed', 2394)]
# 36502::[('640x480', 25)]
# 36575::[('portion', 1170)]
# 36648::[('expressly', 26)]
# 36714::[('lt1081', 4)]
# 36787::[('vehicle', 813)]
# 36860::[('rewording', 911)]
# 36926::[('400mg', 9)]
# 37072::[('indicated', 109)]
# 37138::[('743621', 17)]
# 37211::[('syntax', 217)]
# 37357::[('synonymous', 12)]
# 37423::[('before', 2708)]
# 37496::[('minority', 394)]
# 37569::[('laboratory', 421)]
# 37708::[('infinite', 1158)]
# 37781::[('honourable', 288)]
# 37847::[('burst', 1320)]
# 37920::[('breached', 4)]
# 38059::[('reach', 330)]
# 38271::[('1542bs', 4)]
# 38344::[('impulse', 1442)]
# 38417::[('revolvers', 96)]
# 38483::[('4826394', 2)]
# 38556::[('indiana', 256)]
# 38629::[('companies', 668)]
# 38695::[('hr277', 3)]
# 38768::[('rtheta2', 2)]
# 38841::[('dedicated', 64)]
# 38907::[('500500', 8)]
# 38980::[('etzion', 882)]
# 39119::[('82238', 52)]
# 39192::[('brenda', 357)]
# 39265::[('improves', 286)]
# 39338::[('protection', 382)]
# 39404::[('patch8', 2)]
# 39477::[('dirtbike', 566)]
# 39550::[('annihilate', 158)]
# 39616::[('would', 10800)]
# 39828::[('cache', 147)]
# 39901::[('tolstoy', 8)]
# 40040::[('10mhz', 8)]
# 40113::[('warning', 3596)]
# 40186::[('important', 704)]
# 40252::[('900ss', 7)]
# 40325::[('karabag', 40)]
# 40398::[('knowledge', 939)]
# 40464::[('pc137', 2)]
# 40676::[('3000a', 1)]
# 40749::[('assume', 4133)]
# 40888::[('30332', 67)]
# 40895::[('ruthlessly', 22)]
# 40961::[('decide', 211)]
# 41034::[('insuring', 1230)]
# 41107::[('activities', 445)]
# 41173::[('20apr93', 4)]
# 41246::[('believed', 1234)]
# 41319::[('negotiable', 176)]
# 41385::[('might', 5093)]
# 41458::[('compass2', 2)]
# 41597::[('n8wed', 18)]
# 41670::[('without', 1634)]
# 41743::[('institutt', 2)]
# 41809::[('24bit', 40)]
# 41882::[('nuclear', 2328)]
# 41955::[('thousands', 1243)]
# 42021::[('100ns', 5)]
# 42094::[('button1', 4)]
# 42167::[('concluded', 129)]
# 42233::[('6689k', 6)]
# 42306::[('10baset', 4)]
# 42445::[('0f000', 1)]
# 42518::[('beyond', 2052)]
# 42591::[('horowitz', 10)]
# 42664::[('propulsion', 405)]
# 42730::[('wd4oqc', 111)]
# 42803::[('services', 1473)]
# 42876::[('especially', 847)]
# 42942::[('sorry', 395)]
# 43015::[('chemical', 267)]
# 43088::[('difference', 500)]
# 43154::[('sigma', 1147)]
# 43366::[('w2ehd', 6)]
# 43439::[('purpose', 1228)]
# 43512::[('anxiously', 55)]
# 43578::[('mx15f', 11)]
# 43651::[('because', 4991)]
# 43724::[('bloodiest', 819)]
# 43790::[('x11r3', 24)]
# 43863::[('liasun3', 1)]
# 43936::[('commanded', 56)]
# 44002::[('201088', 8)]
# 44075::[('lerxst', 227)]
# 44214::[('99775', 1)]
# 44287::[('engine', 1538)]
# 44360::[('coventry', 27)]
# 44433::[('eventually', 357)]
# 44499::[('drdos6', 1)]
# 44572::[('troubled', 623)]
# 44645::[('inflicting', 481)]
# 44711::[('motto', 633)]
# 44784::[('boldface', 5)]
# 44857::[('machanical', 2)]
# 44923::[('place', 1740)]
# 44996::[('ttttttt', 3)]
# 45135::[('icl232', 6)]
# 45208::[('premium', 2476)]
# 45281::[('customary', 51)]
# 45347::[('154xx', 9)]
# 45420::[('advance', 669)]
# 45493::[('therefore', 1883)]
# 45559::[('mr535', 6)]
# 45705::[('traceback', 18)]
# 45771::[('11x10', 8)]
# 45844::[('unless', 1822)]
# 45983::[('46942', 31)]
# 45990::[('supertwist', 1)]
# 46056::[('cradle', 614)]
# 46129::[('missions', 662)]
# 46202::[('controller', 1048)]
# 46268::[('1050meg', 5)]
# 46341::[('machines', 1629)]
# 46414::[('additional', 322)]
# 46480::[('write', 2047)]
# 46553::[('mod2mask', 2)]
# 46692::[('adana', 20)]
# 46765::[('surveys', 19)]
# 46904::[('20mhz', 15)]
# 46977::[('modular', 3001)]
# 47050::[('proposals', 665)]
# 47116::[('fj1100', 6)]
# 47189::[('checked', 157)]
# 47262::[('launching', 708)]
# 47328::[('e001h', 4)]
# 47613::[('pickup', 2016)]
# 47752::[('15213', 54)]
# 47759::[('supervisor', 15)]
# 47825::[('became', 226)]
# 47898::[('wingless', 1275)]
# 47971::[('presenting', 284)]
# 48037::[('32bits', 3)]
# 48110::[('obtained', 572)]
# 48183::[('conference', 294)]
# 48249::[('major', 4258)]
# 48461::[('cb360t', 28)]
# 48534::[('utility', 258)]
# 48673::[('20mph', 13)]
# 48746::[('enemies', 1850)]
# 48819::[('expansion', 1041)]
# 48885::[('500sl', 5)]
# 49031::[('immediate', 463)]
# 49097::[('411989', 16)]
# 49170::[('output', 329)]
# 49243::[('centris610', 3)]
# 49309::[('d4300', 2)]
# 49382::[('scares', 2906)]
# 49455::[('tourists', 7)]
# 49528::[('processors', 59)]
# 49594::[('hb9nby', 88)]
# 49667::[('somebody', 1907)]
# 49740::[('subjective', 1002)]
# 49806::[('yours', 119)]
# 49879::[('barbaric', 48)]
# 49952::[('accredited', 23)]
# 50018::[('bunch', 4097)]
# 50091::[('gehrels3', 7)]
# 50230::[('n5ial', 8)]
# 50303::[('network', 837)]
# 50376::[('seriously', 202)]
# 50442::[('86deg', 8)]
# 50515::[('command', 1929)]
# 50588::[('permanent', 789)]
# 50654::[('543mb', 8)]
# 50800::[('batchfile', 154)]
# 50866::[('105366', 16)]
# 50939::[('thorny', 273)]
# 51151::[('stable', 1504)]
# 51224::[('textures', 59)]
# 51297::[('investment', 430)]
# 51363::[('cgtwo0', 1)]
# 51436::[('consider', 1730)]
# 51509::[('individual', 826)]
# 51575::[('truth', 1661)]
# 51648::[('packaged', 12)]
# 51721::[('dependable', 7)]
# 51787::[('again', 1375)]
# 51933::[('25aircraft', 1)]
# 51999::[('640x400', 11)]
# 52072::[('process', 1662)]
# 52145::[('questions', 889)]
# 52211::[('386sx', 20)]
# 52284::[('blocked', 214)]
# 52357::[('directive', 462)]
# 52423::[('90c030', 6)]
# 52496::[('bcarh829', 2)]
# 52569::[('impeached', 8)]
# 52635::[('x7423', 7)]
# 52708::[('tucson', 802)]
# 52847::[('10598', 21)]
# 52854::[('motorsport', 16)]
# 52920::[('behind', 660)]
# 52993::[('majority', 771)]
# 53066::[('ammunition', 304)]
# 53132::[('xellf2', 2)]
# 53205::[('magazine', 1653)]
# 53278::[('humiliated', 252)]
# 53344::[('ghost', 1090)]
# 53556::[('kc2wz', 16)]
# 53629::[('versyss', 1)]
# 53768::[('12mhz', 9)]
# 53841::[('opposed', 3242)]
# 53914::[('momentary', 268)]
# 53980::[('5560074', 1)]
# 54053::[('bandied', 55)]
# 54126::[('fairbanks', 769)]
# 54192::[('hp720', 7)]
# 54265::[('crchh403', 1)]
# 54338::[('headcoach', 3)]
# 54404::[('t1600', 2)]
# 54477::[('robert', 2367)]
# 54550::[('wcrostxx', 1)]
# 54616::[('06520', 40)]
# 54623::[('newsgroups', 96)]
# 54689::[('celica', 168)]
# 54762::[('unlikely', 1457)]
# 54835::[('mitsubishi', 420)]
# 54901::[('zruty', 5)]
# 54974::[('upgraded', 691)]
# 55047::[('deductible', 41)]
# 55113::[('their', 9533)]
# 55186::[('compass3', 5)]
# 55325::[('3comm', 9)]
# 55398::[('rusnews', 119)]
# 55471::[('luxurious', 3)]
# 55537::[('30mph', 10)]
# 55610::[('meeting', 1731)]
# 55683::[('purifying', 484)]
# 55749::[('117th', 6)]
# 55822::[('button2', 1)]
# 55895::[('massacred', 706)]
# 55961::[('aa185', 3)]
# 56034::[('sporty', 13)]
# 56246::[('people', 7514)]
# 56319::[('surveyor', 7)]
# 56385::[('00000', 1)]
# 56392::[('proponents', 52)]
# 56458::[('wa1tas', 87)]
# 56531::[('enjoying', 1083)]
# 56604::[('capability', 1069)]
# 56670::[('story', 459)]
# 56743::[('boadilla', 37)]
# 56816::[('hildebrand', 28)]
# 56882::[('model', 9494)]
# 56955::[('corolla7', 1)]
# 57094::[('wire4', 5)]
# 57167::[('request', 931)]
# 57240::[('crosspost', 22)]
# 57306::[('13meg', 2)]
# 57379::[('disease', 1137)]
# 57452::[('expressed', 598)]
# 57518::[('x11r4', 81)]
# 57591::[('skibum7', 3)]
# 57664::[('challenge', 188)]
# 57730::[('109147', 9)]
# 57803::[('priory', 179)]
# 57876::[('div1sched', 1)]
# 57942::[('39988', 3)]
# 58015::[('images', 1516)]
# 58088::[('quantity', 86)]
# 58161::[('encryption', 941)]
# 58227::[('disp135', 4)]
# 58300::[('includes', 1612)]
# 58373::[('containing', 419)]
# 58439::[('souls', 575)]
# 58512::[('callback', 43)]
# 58585::[('redeemable', 3)]
# 58651::[('glide', 683)]
# 58863::[('800x600', 41)]
# 58936::[('maximum', 3031)]
# 59009::[('virtually', 148)]
# 59075::[('be41t', 24)]
# 59148::[('escaped', 206)]
# 59221::[('captaincy', 339)]
# 59287::[('100ma', 24)]
# 59360::[('crchh574', 6)]
# 59433::[('concealed', 64)]
# 59499::[('10w40', 22)]
# 59572::[('writes', 764)]
# 59711::[('92717', 32)]
# 59718::[('terrritory', 2)]
# 59784::[('handle', 1141)]
# 59857::[('starters', 183)]
# 59930::[('collisions', 486)]
# 60069::[('presence', 1608)]
# 60142::[('experience', 546)]
# 60208::[('looks', 3454)]
# 60281::[('headache', 24)]
# 60354::[('bridgehead', 5)]
# 60420::[('aided', 27)]
# 60493::[('gsxr1100l', 1)]
# 60632::[('40mhz', 20)]
# 60705::[('finally', 3358)]
# 60778::[('politburo', 205)]
# 60844::[('gd3004', 34)]
# 60917::[('labeled', 55)]
# 60990::[('remaining', 907)]
# 61056::[('hp730', 6)]
# 61129::[('buffer1', 2)]
# 61268::[('t9000', 2)]
# 61341::[('orders', 1295)]
# 61414::[('synopsys', 1)]
# 61480::[('54600', 51)]
# 61487::[('monsterous', 3)]
# 61553::[('wb7tza', 16)]
# 61626::[('northern', 792)]
# 61699::[('condensers', 1624)]
# 61765::[('56kbps', 4)]
# 61838::[('recorded', 870)]
# 61911::[('reasonable', 401)]
# 61977::[('sense', 7421)]
# 62189::[('4megs', 12)]
# 62262::[('grossly', 96)]
# 62401::[('50ohm', 7)]
# 62474::[('thermal', 1421)]
# 62547::[('otherwise', 598)]
# 62613::[('cb1000', 3)]
# 62759::[('anecdotal', 433)]
# 62825::[('645659', 5)]
# 62898::[('accord2', 11)]
# 62971::[('grafsys3d', 2)]
# 63037::[('a2630', 4)]
# 63044::[('sloooowwww', 1)]
# 63110::[('ignore', 2042)]
# 63183::[('sysquest', 17)]
# 63249::[('10000', 4)]
# 63256::[('complexity', 183)]
# 63322::[('wb2jsj', 53)]
# 63395::[('floppies', 1935)]
# 63468::[('mcwilliams', 319)]
# 63534::[('strut', 21)]
# 63607::[('pasadena', 688)]
# 63680::[('referenced', 130)]
# 63746::[('brave', 1708)]
# 63958::[('832x624', 9)]
# 64031::[('winters', 1540)]
# 64104::[('survivers', 3)]
# 64170::[('68hc11', 2)]
# 64243::[('weekend', 3678)]
# 64316::[('considers', 1087)]
# 64382::[('x11r5', 164)]
# 64455::[('mvg4cpd', 1)]
# 64528::[('gambarian', 28)]
# 64594::[('1200x', 9)]
# 64667::[('rumors', 145)]
# 64879::[('please', 5498)]
# 64952::[('autopost', 77)]
# 65025::[('horsepower', 43)]
# 65091::[('wa3nan', 4)]
# 65164::[('needless', 1626)]
# 65237::[('centerline', 306)]
# 65303::[('tumor', 460)]
# 65376::[('defended', 14)]
# 65449::[('accordance', 42)]
# 65515::[('heard', 2400)]
# 65727::[('00000074', 19)]
# 65800::[('turning', 1397)]
# 65873::[('obnoxious', 49)]
# 65939::[('win32', 14)]
# 66012::[('adaptec', 260)]
# 66085::[('presented', 1065)]
# 66151::[('kz650', 6)]
# 66297::[('sciamanda', 9)]
# 66363::[('152140', 4)]
# 66436::[('lovers', 919)]
# 66575::[('11797', 26)]
# 66582::[('expository', 1)]
# 66648::[('jammed', 1079)]
# 66721::[('glorious', 620)]
# 66794::[('impressive', 271)]
# 66860::[('00000ee5', 2)]
# 66933::[('hardware', 1668)]
# 67006::[('whiteheads', 38)]
# 67072::[('doors', 2940)]
# 67284::[('cable', 261)]
# 67496::[('50mhz', 31)]
# 67569::[('solicit', 2306)]
# 67642::[('responses', 472)]
# 67708::[('cd4052', 11)]
# 67781::[('reached', 350)]
# 67854::[('political', 1047)]
# 67920::[('lm225', 3)]
# 67993::[('buffer2', 2)]
# 68066::[('cavalcade', 1)]
# 68132::[('100000', 4)]
# 68205::[('values', 2778)]
# 68344::[('08502', 58)]
# 68351::[('luminosity', 2)]
# 68417::[('amanda', 88)]
# 68490::[('restrict', 466)]
# 68563::[('econoboxes', 262)]
# 68702::[('accident', 731)]
# 68775::[('electrical', 364)]
# 68841::[('seems', 2793)]
# 68914::[('compass4', 2)]
# 69053::[('mst3k', 11)]
# 69126::[('history', 439)]
# 69199::[('surveyors', 3)]
# 69265::[('r80gs', 12)]
# 69338::[('orbital', 2128)]
# 69411::[('restoring', 1087)]
# 69477::[('325is', 9)]
# 69550::[('mol2scn', 3)]
# 69623::[('depending', 422)]
# 69689::[('hc811', 2)]
# 69974::[('center', 2960)]
# 70047::[('throwout', 1)]
# 70113::[('02000', 2)]
# 70120::[('postscript', 187)]
# 70186::[('esun228', 24)]
# 70259::[('assembly', 938)]
# 70332::[('burdensome', 339)]
# 70398::[('worry', 139)]
# 70471::[('attached', 216)]
# 70544::[('incredible', 49)]
# 70610::[('green', 3094)]
# 70822::[('1280xl', 4)]
# 70895::[('windows', 1810)]
# 70968::[('optometry', 19)]
# 71034::[('12vdc', 9)]
# 71107::[('meaning', 1606)]
# 71180::[('handiwork', 496)]
# 71246::[('x11r6', 5)]
# 71319::[('scn2sff', 1)]
# 71392::[('mislabled', 86)]
# 71458::[('850472', 5)]
# 71531::[('flurry', 103)]
# 71670::[('88888', 3)]
# 71743::[('double', 1783)]
# 71816::[('treasury', 49)]
# 71889::[('structural', 108)]
# 72028::[('possible', 1833)]
# 72101::[('federation', 377)]
# 72167::[('tommy', 248)]
# 72240::[('defiance', 31)]
# 72313::[('achaemenid', 6)]
# 72379::[('chalk', 1058)]
# 72591::[('k1hhc', 5)]
# 72664::[('hewlett', 1338)]
# 72737::[('diversity', 51)]
# 72803::[('98604s', 3)]
# 72876::[('teenage', 720)]
# 72949::[('committed', 1227)]
# 73015::[('xv221', 20)]
# 73161::[('succeeded', 90)]
# 73227::[('20w50', 12)]
# 73300::[('insist', 550)]
# 73439::[('77058', 17)]
# 73446::[('motosports', 1)]
# 73512::[('camtec', 601)]
# 73585::[('workshop', 138)]
# 73658::[('government', 1655)]
# 73724::[('1200dpi', 6)]
# 73797::[('engineer', 792)]
# 73870::[('culminated', 235)]
# 73936::[('front', 2619)]
# 74082::[('manageable', 3)]
# 74148::[('lp240s', 18)]
# 74360::[('00110011', 3)]
# 74433::[('rigidly', 1674)]
# 74506::[('witnesses', 232)]
# 74572::[('240sx', 5)]
# 74645::[('changed', 685)]
# 74718::[('legislate', 497)]
# 74996::[('4m312', 15)]
# 75069::[('purdue', 2547)]
# 75208::[('27511', 87)]
# 75215::[('mysterious', 41)]
# 75281::[('chance', 341)]
# 75354::[('requires', 1145)]
# 75427::[('originally', 562)]
# 75493::[('ds1489n', 4)]
# 75566::[('intended', 909)]
# 75639::[('encouraged', 132)]
# 75705::[('right', 5741)]
# 75778::[('80mflops', 1)]
# 75917::[('arm6x', 1)]
# 75990::[('utterly', 60)]
# 76063::[('survivors', 30)]
# 76129::[('60mph', 12)]
# 76202::[('between', 3820)]
# 76275::[('controler', 1040)]
# 76414::[('3finger', 1)]
# 76487::[('sentenced', 214)]
# 76553::[('pb140', 4)]
# 76626::[('spotty', 14)]
# 76765::[('0b800', 3)]
# 76838::[('market', 3971)]
# 76911::[('unworthy', 35)]
# 76977::[('10020', 15)]
# 76984::[('provisions', 95)]
# 77050::[('decade', 50)]
# 77123::[('proposed', 1225)]
# 77196::[('dashnakist', 308)]
# 77262::[('proxy', 8)]
# 77335::[('lockheed', 107)]
# 77408::[('concidered', 63)]
# 77474::[('makes', 5325)]
# 77547::[('bbbbbbbb', 3)]
# 77686::[('752x580', 5)]
# 77759::[('monthly', 236)]
# 77832::[('shortstop', 22)]
# 77898::[('am9568', 3)]
# 77971::[('upgrade', 1305)]
# 78044::[('vaporized', 481)]
# 78110::[('0x37f', 10)]
# 78256::[('callbacks', 50)]
# 78322::[('680x0', 27)]
# 78395::[('versus', 117)]
# 78607::[('looked', 2553)]
# 78680::[('destroys', 36)]
# 78753::[('extenstion', 115)]
# 78819::[('4000bps', 1)]
# 78892::[('forecast', 1040)]
# 78965::[('unexpected', 450)]
# 79031::[('hurts', 478)]
# 79104::[('cambodia', 38)]
# 79177::[('mechanical', 81)]
# 79243::[('nagle', 550)]
# 79455::[('352x240', 1)]
# 79528::[('thought', 3430)]
# 79601::[('newsgroup', 788)]
# 79667::[('7911859', 2)]
# 79740::[('machine', 859)]
# 79813::[('pharisees', 1029)]
# 79879::[('120lb', 15)]
# 79952::[('bmdhh299', 13)]
# 80025::[('descended', 40)]
# 80091::[('680020', 19)]
# 80164::[('parity', 1400)]
# 80303::[('75088', 12)]
# 80310::[('newsworthy', 1)]
# 80376::[('barden', 475)]
# 80449::[('solution', 380)]
# 80522::[('statistics', 483)]
# 80588::[('sense1', 1)]
# 80661::[('condense', 773)]
# 80734::[('interfered', 177)]
# 80800::[('quote', 3741)]
# 80873::[('leadacid', 1)]
# 81012::[('bajaj', 29)]
# 81085::[('outputs', 29)]
# 81224::[('33mhz', 25)]
# 81297::[('caution', 2106)]
# 81370::[('summarily', 181)]
# 81436::[('ba5406', 2)]
# 81509::[('defence', 158)]
# 81582::[('allegedly', 781)]
# 81648::[('r100c', 7)]
# 81860::[('p1390', 2)]
# 81933::[('christ', 1875)]
# 82072::[('38240', 58)]
# 82079::[('terrorists', 61)]
# 82145::[('needed', 586)]
# 82218::[('holocost', 1241)]
# 82291::[('techniques', 347)]
# 82357::[('74hc4066', 1)]
# 82430::[('practice', 511)]
# 82503::[('economical', 110)]
# 82569::[('nerve', 2332)]
# 82642::[('compass5', 2)]
# 82781::[('n0itl', 5)]
# 82854::[('puzzles', 61)]
# 82993::[('70mph', 6)]
# 83066::[('friends', 2106)]
# 83139::[('documents', 758)]
# 83205::[('0004246', 2)]
# 83278::[('alabama', 44)]
# 83351::[('compelled', 341)]
# 83417::[('cj360', 7)]
# 83490::[('zumrut', 4)]
# 83629::[('0c800', 2)]
# 83702::[('weitek', 3131)]
# 83775::[('supports', 245)]
# 83841::[('21001', 1)]
# 83848::[('viewpoints', 24)]
# 83914::[('canada', 537)]
# 83987::[('publicly', 1298)]
# 84060::[('substances', 287)]
# 84126::[('alpha0', 1)]
# 84199::[('genocide', 565)]
# 84272::[('negligible', 76)]
# 84338::[('calls', 3261)]
# 84550::[('3dmod', 4)]
# 84623::[('summary', 1037)]
# 84696::[('outskirts', 13)]
# 84762::[('nr10s', 1)]
# 84835::[('message', 1808)]
# 84908::[('inability', 497)]
# 84974::[('86c805', 11)]
# 85120::[('technical', 431)]
# 85186::[('382761', 63)]
# 85259::[('mostly', 267)]
# 85398::[('a1000', 1)]
# 85471::[('ducati', 2322)]
# 85544::[('forestry', 67)]
# 85617::[('missionary', 209)]
# 85683::[('wa1ivb', 3)]
# 85756::[('required', 1112)]
# 85829::[('explaining', 390)]
# 85895::[('ports', 736)]
# 85968::[('demanded', 31)]
# 86041::[('unbalanced', 15)]
# 86107::[('being', 3561)]
# 86319::[('gen0n', 7)]
# 86392::[('control', 2552)]
# 86465::[('hostility', 92)]
# 86531::[('win16', 13)]
# 86604::[('science', 1374)]
# 86677::[('committee', 1926)]
# 86743::[('210mb', 27)]
# 86816::[('cgfour0', 2)]
# 86889::[('clearance', 25)]
# 86955::[('680030', 5)]
# 87028::[('points', 1094)]
# 87167::[('94088', 7)]
# 87174::[('usurpatory', 1)]
# 87240::[('locked', 992)]
# 87313::[('advisory', 154)]
# 87386::[('population', 525)]
# 87452::[('video7', 3)]
# 87525::[('jonathan', 1458)]
# 87598::[('prohibited', 218)]
# 87664::[('power', 2631)]
# 87737::[('feedback', 46)]
# 87810::[('detachable', 5)]
# 87876::[('n3jxp', 115)]
# 88088::[('25mhz', 31)]
# 88161::[('massive', 2065)]
# 88234::[('pessimist', 197)]
# 88300::[('me55a', 4)]
# 88373::[('fiddled', 63)]
# 88446::[('precedent', 147)]
# 88585::[('et4000ax', 1)]
# 88658::[('decodable', 1)]
# 88724::[('3401b', 13)]
# 88797::[('willis', 3158)]
# 88936::[('16550', 165)]
# 88943::[('herskowitz', 6)]
# 89009::[('behalf', 105)]
# 89082::[('opinions', 1038)]
# 89155::[('propellant', 210)]
# 89221::[('wb1hbb', 4)]
# 89294::[('heritage', 223)]
# 89367::[('percentage', 231)]
# 89433::[('about', 10224)]
# 89645::[('gs850g', 8)]
# 89718::[('country', 334)]
# 89857::[('10fps', 7)]
# 89930::[('realize', 2421)]
# 90003::[('equipment', 561)]
# 90069::[('500mv', 1)]
# 90142::[('rebecca', 1)]
# 90215::[('fulfilled', 536)]
# 90281::[('cl350', 2)]
# 90354::[('accord4', 2)]
# 90427::[('academica', 1)]
# 90493::[('p1100', 1)]
# 90566::[('number', 4381)]
# 90639::[('shutouts', 10)]
# 90705::[('01003', 10)]
# 90712::[('powerfully', 125)]
# 90778::[('babied', 3)]
# 90851::[('whatever', 2155)]
# 90924::[('utterances', 132)]
# 90990::[('totty', 8)]
# 91063::[('achieved', 407)]
# 91136::[('bangaldesh', 86)]
# 91202::[('great', 4816)]
# 91414::[('n4zbb', 14)]
# 91487::[('writers', 309)]
# 91560::[('tommorrow', 7)]
# 91626::[('ds1488', 3)]
# 91699::[('article', 8191)]
# 91772::[('following', 1082)]
# 91838::[('535ii', 7)]
# 91911::[('pixmap8', 2)]
# 91984::[('allocated', 235)]
# 92050::[('164871', 5)]
# 92123::[('pretty', 726)]
# 92196::[('égligent', 1)]
# 92262::[('a2000', 2)]
# 92335::[('actual', 1559)]
# 92408::[('ministry', 78)]
# 92481::[('supporting', 280)]
# 92547::[('wd0dbx', 6)]
# 92620::[('probably', 2099)]
# 92693::[('habitation', 244)]
# 92759::[('spots', 191)]
# 92832::[('conceded', 22)]
# 92905::[('candelaria', 11)]
# 92971::[('brief', 1462)]
# 93183::[('640x800', 7)]
# 93256::[('roberts', 861)]
# 93329::[('solutions', 100)]
# 93395::[('ar44l', 2)]
# 93468::[('created', 665)]
# 93541::[('introduce', 738)]
# 93607::[('130mb', 3)]
# 93680::[('bmerh824', 9)]
# 93753::[('fastcache', 10)]
# 93819::[('221370', 7)]
# 93892::[('floppy', 660)]
# 94031::[('35894', 29)]
# 94104::[('tended', 1288)]
# 94177::[('warranty', 249)]
# 94250::[('punishment', 684)]
# 94316::[('32plus', 1)]
# 94389::[('convince', 1176)]
# 94462::[('references', 399)]
# 94528::[('jesus', 2308)]
# 94601::[('cascaded', 1)]
# 94740::[('110vac', 174)]
# 94952::[('sec001', 6)]
# 95025::[('sweeper', 953)]
# 95098::[('promotion', 333)]
# 95164::[('22621u', 6)]
# 95237::[('cracked', 87)]
# 95310::[('louisiana', 1118)]
# 95376::[('xj600', 1)]
# 95522::[('enchilada', 2)]
# 95588::[('g8870', 10)]
# 95661::[('stupid', 1204)]
# 95734::[('zyxel1496b', 1)]
# 95800::[('91711', 90)]
# 95807::[('enormously', 8)]
# 95873::[('fanged', 89)]
# 95946::[('customer', 707)]
# 96019::[('oscillator', 359)]
# 96085::[('hp48sx', 7)]
# 96158::[('handling', 897)]
# 96231::[('commercial', 413)]
# 96297::[('other', 12557)]
# 96370::[('compass6', 2)]
# 96509::[('n4zhg', 11)]
# 96582::[('pursuit', 52)]
# 96655::[('statutory', 6)]
# 96721::[('24pin', 2)]
# 96794::[('problem', 4280)]
# 96867::[('wisconsin', 483)]
# 96933::[('366th', 4)]
# 97006::[('scabbed', 6)]
# 97079::[('sadducees', 431)]
# 97145::[('pb160', 4)]
# 97218::[('x11perf', 3)]
# 97357::[('c1381', 1)]
# 97430::[('faster', 3651)]
# 97503::[('russotto', 5)]
# 97569::[('60000', 15)]
# 97576::[('kazoostorm', 24)]
# 97642::[('ka1lpw', 8)]
# 97715::[('actually', 2808)]
# 97788::[('particular', 768)]
# 97854::[('louzy', 2)]
# 97927::[('modified', 334)]
# 98000::[('propaganda', 159)]
# 98066::[('after', 5842)]
# 98278::[('emm386', 21)]
# 98351::[('unknown', 340)]
# 98424::[('territory', 60)]
# 98490::[('1000cc', 5)]
# 98563::[('stalled', 1098)]
# 98636::[('cruelties', 606)]
# 98702::[('222hp', 7)]
# 98848::[('interface', 392)]
# 98914::[('692255', 12)]
# 98987::[('sports', 227)]
# 99126::[('a1200', 4)]
# 99199::[('taking', 2302)]
# 99272::[('stimulus', 71)]
# 99345::[('situations', 141)]
# 99411::[('ve6dau', 1)]
# 99484::[('callison', 1345)]
# 99557::[('windscreen', 197)]
# 99623::[('towns', 305)]
# 99696::[('canadian', 163)]
# 99769::[('sacrificed', 19)]
# 99835::[('board', 3375)]
# 100047::[('1762dt', 13)]
# 100120::[('version', 2475)]
# 100193::[('testimony', 93)]
# 100259::[('nx2000', 5)]
# 100332::[('reduced', 599)]
# 100405::[('wondering', 997)]
# 100471::[('l10861', 16)]
# 100544::[('bcars194', 2)]
# 100617::[('available', 1385)]
# 100683::[('680040', 6)]
# 100756::[('errors', 1771)]
# 100895::[('19947', 4)]
# 100968::[('dealer', 763)]
# 101041::[('shotguns', 137)]
# 101114::[('recompress', 391)]
# 101180::[('vivid2', 5)]
# 101253::[('graphics', 1605)]
# 101326::[('christiaan', 241)]
# 101392::[('known', 4926)]
# 101465::[('academia', 13)]
# 101538::[('barehanded', 1)]
# 101604::[('peace', 345)]
# 101677::[('v65sabre', 2)]
# 101816::[('320x200', 11)]
# 101889::[('anybody', 1834)]
# 101962::[('viewpoint', 248)]
# 102028::[('1564672', 4)]
# 102101::[('grenada', 112)]
# 102174::[('armistice', 297)]
# 102240::[('rm125', 9)]
# 102313::[('40mbtye', 1)]
# 102386::[('reachable', 3)]
# 102452::[('x2313', 2)]
# 102525::[('sooner', 1266)]
# 102664::[('04473', 63)]
# 102671::[('university', 4601)]
# 102737::[('failed', 428)]
# 102810::[('computer', 2210)]
# 102883::[('protective', 230)]
# 102949::[('1000ff06', 1)]
# 103022::[('delaware', 770)]
# 103095::[('mechanized', 134)]
# 103161::[('early', 2900)]
# 103234::[('station2', 3)]
# 103373::[('k1kyi', 2)]
# 103446::[('erzurum', 25)]
# 103519::[('survivour', 1)]
# 103585::[('55mph', 17)]
# 103658::[('several', 2378)]
# 103731::[('restraint', 642)]
# 103797::[('2515251', 3)]
# 103870::[('decided', 301)]
# 103943::[('detailing', 319)]
# 104009::[('cr500', 11)]
# 104082::[('00index', 3)]
# 104294::[('around', 4201)]
# 104367::[('virtuous', 4)]
# 104433::[('50011', 11)]
# 104440::[('zoologists', 41)]
# 104506::[('ka2czu', 1)]
# 104579::[('starting', 1771)]
# 104652::[('apocalypse', 294)]
# 104718::[('putty', 2)]

# %%
len(palabras)
# Out:
# 826942
